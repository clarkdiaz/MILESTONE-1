# %%
import pandas as pd

# Load IoT sensor data from CSV (Generated in Homework 1)
df = pd.read_csv("resources/smart_logistics_data.csv")

# Display the first few rows
print(df.head())
# Out:
#   shipment_id                   timestamp    gps_lat    gps_long  rfid_tag  \
# 0   SHP980988  2025-05-15 13:52:59.194834  11.721861  122.739816  RFID1098
# 1   SHP650973  2025-05-15 07:19:59.194993  13.051399  121.518155  RFID1063
# 2   SHP339067  2025-05-15 05:03:59.195050  13.867232  122.339907  RFID1010
# 3   SHP328994  2025-05-15 20:11:59.195101  14.814776  122.012883  RFID1096
# 4   SHP634775  2025-05-15 15:02:59.195151  10.127991  120.478309  RFID1037
#
#    package_temp_c  humidity_percent            status
# 0            6.80             43.68        In Transit
# 1            9.49             59.35    Arrived at Hub
# 2            6.63             34.58           Delayed
# 3            9.23             30.99           Delayed
# 4            8.04             46.65  Out for Delivery

# %%
from web3 import Web3


# Connect to local blockchain
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))


# Verify connection
if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
# Out:
# ✅ Connected to Ganache successfully!

# %%
contract_address = "0x3AF9Cb6ae4EA87Bc4178A74c7700f1868C807c20"


# Paste the ABI from Remix
abi = abi = [
  {
    "inputs": [],
    "stateMutability": "nonpayable",
    "type": "constructor"
  },
  {
    "anonymous": False,
    "inputs": [
      {
        "indexed": False,
        "internalType": "uint256",
        "name": "timestamp",
        "type": "uint256"
      },
      {
        "indexed": False,
        "internalType": "string",
        "name": "deviceId",
        "type": "string"
      },
      {
        "indexed": False,
        "internalType": "string",
        "name": "dataType",
        "type": "string"
      },
      {
        "indexed": False,
        "internalType": "string",
        "name": "dataValue",
        "type": "string"
      }
    ],
    "name": "IoTDataStored",
    "type": "event"
  },
  {
    "anonymous": False,
    "inputs": [
      {
        "indexed": True,
        "internalType": "string",
        "name": "packageId",
        "type": "string"
      },
      {
        "indexed": True,
        "internalType": "string",
        "name": "dataType",
        "type": "string"
      },
      {
        "indexed": False,
        "internalType": "string",
        "name": "value",
        "type": "string"
      }
    ],
    "name": "PackageDataStored",
    "type": "event"
  },
  {
    "inputs": [],
    "name": "MAX_IOT_ENTRIES",
    "outputs": [
      {
        "internalType": "uint256",
        "name": "",
        "type": "uint256"
      }
    ],
    "stateMutability": "view",
    "type": "function"
  },
  {
    "inputs": [
      {
        "internalType": "uint256",
        "name": "index",
        "type": "uint256"
      }
    ],
    "name": "getIoTRecord",
    "outputs": [
      {
        "internalType": "uint256",
        "name": "",
        "type": "uint256"
      },
      {
        "internalType": "string",
        "name": "",
        "type": "string"
      },
      {
        "internalType": "string",
        "name": "",
        "type": "string"
      },
      {
        "internalType": "string",
        "name": "",
        "type": "string"
      }
    ],
    "stateMutability": "view",
    "type": "function"
  },
  {
    "inputs": [
      {
        "internalType": "string",
        "name": "packageId",
        "type": "string"
      },
      {
        "internalType": "string",
        "name": "dataType",
        "type": "string"
      }
    ],
    "name": "getPackageData",
    "outputs": [
      {
        "internalType": "string",
        "name": "",
        "type": "string"
      }
    ],
    "stateMutability": "view",
    "type": "function"
  },
  {
    "inputs": [],
    "name": "getTotalIoTRecords",
    "outputs": [
      {
        "internalType": "uint256",
        "name": "",
        "type": "uint256"
      }
    ],
    "stateMutability": "view",
    "type": "function"
  },
  {
    "inputs": [
      {
        "internalType": "uint256",
        "name": "",
        "type": "uint256"
      }
    ],
    "name": "iotDataRecords",
    "outputs": [
      {
        "internalType": "uint256",
        "name": "timestamp",
        "type": "uint256"
      },
      {
        "internalType": "string",
        "name": "deviceId",
        "type": "string"
      },
      {
        "internalType": "string",
        "name": "dataType",
        "type": "string"
      },
      {
        "internalType": "string",
        "name": "dataValue",
        "type": "string"
      }
    ],
    "stateMutability": "view",
    "type": "function"
  },
  {
    "inputs": [],
    "name": "owner",
    "outputs": [
      {
        "internalType": "address",
        "name": "",
        "type": "address"
      }
    ],
    "stateMutability": "view",
    "type": "function"
  },
  {
    "inputs": [],
    "name": "populateWithSamplePackageData",
    "outputs": [],
    "stateMutability": "nonpayable",
    "type": "function"
  },
  {
    "inputs": [
      {
        "internalType": "string",
        "name": "packageId",
        "type": "string"
      }
    ],
    "name": "resetPackageData",
    "outputs": [],
    "stateMutability": "nonpayable",
    "type": "function"
  },
  {
    "inputs": [
      {
        "internalType": "string",
        "name": "deviceId",
        "type": "string"
      },
      {
        "internalType": "string",
        "name": "dataType",
        "type": "string"
      },
      {
        "internalType": "string",
        "name": "dataValue",
        "type": "string"
      }
    ],
    "name": "storeIoTData",
    "outputs": [],
    "stateMutability": "nonpayable",
    "type": "function"
  },
  {
    "inputs": [
      {
        "internalType": "string",
        "name": "packageId",
        "type": "string"
      },
      {
        "internalType": "string",
        "name": "dataType",
        "type": "string"
      },
      {
        "internalType": "string",
        "name": "value",
        "type": "string"
      }
    ],
    "name": "storePackageData",
    "outputs": [],
    "stateMutability": "nonpayable",
    "type": "function"
  }
]  # Replace with your contract ABI


# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)


# Set default sender (first account from Ganache)
web3.eth.default_account = web3.eth.accounts[0]

print(f"✅ Connected to Smart Contract at {contract_address}")
# Out:
# ✅ Connected to Smart Contract at 0x3AF9Cb6ae4EA87Bc4178A74c7700f1868C807c20

# %%
import time

def send_iot_data(device_id, data_type, data_value):
    """
    Sends IoT data to the deployed smart contract.
    """
    try:
        # Create and send the transaction
        txn = contract.functions.storeIoTData(device_id, data_type, data_value).transact({
            'from': web3.eth.default_account,
            'gas': 3000000
        })
        # Wait for the transaction receipt
        receipt = web3.eth.wait_for_transaction_receipt(txn)
        print(f"✅ Data Stored: {data_type} - {data_value}, Txn Hash: {receipt.transactionHash.hex()}")
    except Exception as e:
        print(f"❌ Failed to store data: {e}")

# Loop through the DataFrame and send each row to the blockchain
print("🚀 Sending IoT data to the blockchain...")
for _, row in df.iterrows():
    send_iot_data(
        str(row["rfid_tag"]),  # Replace with the correct column name if different
        "temperature",
        str(row["package_temp_c"])  # Replace with the correct column name if different
    )
    time.sleep(1)  # Delay to prevent flooding transactions

# Retrieve and verify storage
try:
    total_records = contract.functions.getTotalIoTRecords().call()
    print(f"📊 Total IoT records stored: {total_records}")

    # Retrieve and print the first stored record
    if total_records > 0:
        record = contract.functions.getIoTRecord(0).call()
        print("📄 First Stored Record:", record)
    else:
        print("⚠️ No records found on the blockchain.")
except Exception as e:
    print(f"❌ Failed to retrieve records: {e}")
# Out:
# 🚀 Sending IoT data to the blockchain...
# ✅ Data Stored: temperature - 6.8, Txn Hash: 46e963f162012696ff06b516030b786be78bdc108862495f4fc2d6f0b1729a5d
# ✅ Data Stored: temperature - 9.49, Txn Hash: 31d1c5e3bf69c98b34a358852b10e3eaa76598be47322709d5805de3ee9e9134
# ✅ Data Stored: temperature - 6.63, Txn Hash: b44f12fa69825e4b283815534529c6e76d4041437334917ac86fb9d54b8498a3
# ✅ Data Stored: temperature - 9.23, Txn Hash: f25f2d4161372989814fa7222da4736557dbf3d388d97216e2d41f8655edea2a
# ✅ Data Stored: temperature - 8.04, Txn Hash: 825e391630ff3ab1d76e65201c7de57948acaba69ec923ed2ec7202674103634
# ✅ Data Stored: temperature - 5.89, Txn Hash: 252a5596a67acb28be8a22616787814df51fd4021a7484949e8e556207f203f3
# ✅ Data Stored: temperature - 6.94, Txn Hash: 4e1b6eefe1c68861eef838253e65bcbf951bd7dd21b75e4654b63e244a953d3c
# ✅ Data Stored: temperature - 2.59, Txn Hash: 3d782acbce21f4dbfc120922dfa6e7dc2904c872892ae4d24f1ad16f8df37307
# ✅ Data Stored: temperature - 3.49, Txn Hash: 165bbc39da905eee617fc93646c4c5c8e1f45b02244430e1760734c491d28d04
# ✅ Data Stored: temperature - 3.43, Txn Hash: b3b5cb1c3d9e34a4f267f1c96f161100b85f1764b70f092b1206528f7a466602
# ✅ Data Stored: temperature - 4.12, Txn Hash: de1610295146cdc8126546fbc51abccacf1520d8983f8e66369daf723fa6a9a5
# ✅ Data Stored: temperature - 3.8, Txn Hash: 187d6a193beb90d94bbfb105b6d46eed4b8949100b684b4c4e0e4ea7657abfac
# ✅ Data Stored: temperature - 3.61, Txn Hash: 6e2336fb4470f5bb92020939b9587ce2fb51a26341961244f681f3c1bebcb416
# ✅ Data Stored: temperature - 7.19, Txn Hash: f9f8083fe611b24098c60379fc0c14bb61878aa2f84cc2ebdffbabaccac2eeaf
# ✅ Data Stored: temperature - 6.84, Txn Hash: 0ccfb9a55bdd1b24b99e02c6bc95987f332b42a78ed78854cb018b9e217f5dba
# ✅ Data Stored: temperature - 4.38, Txn Hash: 61d8797e09a7c0d1ea177eaf8dcbf13cf5a961b92f3c33aae8540843e63cfd11
# ✅ Data Stored: temperature - 7.9, Txn Hash: 50e71682589b6b4130c40c84109cc7cf1bbebdd9b5c349308df8d078b6b88385
# ✅ Data Stored: temperature - 2.6, Txn Hash: 432520dae3b0e4db7d7db22dd310bebb18f3ccc758dba18f3358fd32cee53fc5
# ✅ Data Stored: temperature - 5.31, Txn Hash: b7a528670db28e0982c9f9d93177bce04bdde9943e746315b8a3523256c33221
# ✅ Data Stored: temperature - 4.34, Txn Hash: aab8f69471ca0bec78bb68fe5d5357ba29afd0834d8f569fd399b5770b38d38d
# ✅ Data Stored: temperature - 5.34, Txn Hash: a2c264212b744c51a2308beffa9b9e11cdc42edb3ee19afc7b6ed645eaf4c2a6
# ✅ Data Stored: temperature - 7.2, Txn Hash: a893fd15bfe8c2d4dd5176fb3a2db69cf0250e1eb34020faa5c758d8c1b2a1c9
# ✅ Data Stored: temperature - 7.38, Txn Hash: 71038cf4a241020a400a859e135aafd5f6a566dbb1aafeacd181c4f6c6d5759a
# ✅ Data Stored: temperature - 7.58, Txn Hash: 7e4d9ed5e10b3a8175fd5890435e36413cb98dc8fec63f4d8316b05e43329917
# ✅ Data Stored: temperature - 3.82, Txn Hash: bf2d44c95f1d3690dbe3a08500adc8a92a2fb81320c2ca6ddc7d41ad04d25221
# ✅ Data Stored: temperature - 3.3, Txn Hash: 8e8b87f78c6a1eeb729bda6fdcf7fd1d7041a70a10d0d885b62fdf2ff4bd0991
# ✅ Data Stored: temperature - 6.55, Txn Hash: 9f184eb8a866ef6729022d75fa54d7e3776b9c2a05a91fe77dfb1af61a818887
# ✅ Data Stored: temperature - 9.29, Txn Hash: 0d53bc37f54750562979f8b9b4f569b8156339997bfab672b01e8fecad2466fa
# ✅ Data Stored: temperature - 6.38, Txn Hash: a7e92c4276c891da169ecc628eb20d7232462a78496154ce20ef29dd0c263aad
# ✅ Data Stored: temperature - 5.62, Txn Hash: a43445a1deea48a1795d715cf3329f60d66ec22c6a76c582098848638f334ccc
# ✅ Data Stored: temperature - 2.31, Txn Hash: 080c634fc62a9ffacb1bca4cd9d0b8a59d699dc89db46ec96fa963a9fcb8ee9f
# ✅ Data Stored: temperature - 6.83, Txn Hash: 5c4005180afda9a62ad5fcb44e180dbccd2d86d297a659467d0ed560cd911147
# ✅ Data Stored: temperature - 3.91, Txn Hash: 5f4831bc9fa71d079b25d3ae68a2b3d0d8eceb42b3d535186f6b7463ab0a3a23
# ✅ Data Stored: temperature - 8.08, Txn Hash: fd61b19c5ba8b4e4e599845d4b4c0f00556f637f769d7d99913685696f5f630d
# ✅ Data Stored: temperature - 5.01, Txn Hash: faf6534dc9e4b9f773e1f075db7119efa8ce96ec8f6f4a70e736ed162798b61b
# ✅ Data Stored: temperature - 8.88, Txn Hash: 749ce0eef015f1f5b7af6110e20fce311d05d3921fe79425787f60c4e16f7d67
# ✅ Data Stored: temperature - 5.81, Txn Hash: 33c336fcdc8c813c767e3199ea952c9c810083161bc5447bdb9495625c410cfa
# ✅ Data Stored: temperature - 5.31, Txn Hash: 602a13e5f8d3d3df8649588ac485d97e1612bdfb8a3b26150001c2aa422d4a40
# ✅ Data Stored: temperature - 5.21, Txn Hash: cede7a16b2233bd52e569ac389d1cb8935a10483093015cb9709987c18ff2248
# ✅ Data Stored: temperature - 9.72, Txn Hash: a41244db78094487890d197ff77b9895d2f7c3903714015e479d029e2c39550a
# ✅ Data Stored: temperature - 3.65, Txn Hash: 821aab8175ccd2d7f09a0674cb285682dd9d382483254349ea2f8ef7b986c4ac
# ✅ Data Stored: temperature - 7.76, Txn Hash: 5e55456dc39c2b34297210bdd1850c3b9f65d863042af9c41c363066534f091c
# ✅ Data Stored: temperature - 4.29, Txn Hash: 702083d6e79186ddf6e0841d8f9fbf7fc335cb45fed3776157545763bfec004a
# ✅ Data Stored: temperature - 3.67, Txn Hash: 9c3224e38c9b73018c80e4e46eccc2acb9d0052feee0c935343395dee5cdaa71
# ✅ Data Stored: temperature - 5.79, Txn Hash: 53e3079531ddb550f09b2b72c6d5d2ce7322c1ad2ee3a867dfa744fbd8b723df
# ✅ Data Stored: temperature - 5.33, Txn Hash: 40df3a00ce86120ee8f953d67737cbd6673711089e73f7aa801a00c33d4c7c0d
# ✅ Data Stored: temperature - 4.63, Txn Hash: bfcefefc74799c60404decb5ae0ee6b7cb5d90de22eec234bde10bb992db6252
# ✅ Data Stored: temperature - 7.3, Txn Hash: 5b050a3ce2a5c77fefe7f10a676c1e103a88514371be2b5550cdea05e22769e4
# ✅ Data Stored: temperature - 5.2, Txn Hash: 28b1197978f236acb6565f8e5378a595f79612e50348b29d611fdb8d0cc5d441
# ✅ Data Stored: temperature - 7.26, Txn Hash: 4f318731385574ceee834781f1fd2977d28b429816c03c1ac5ce84d310bd6da8
# ✅ Data Stored: temperature - 6.86, Txn Hash: 598e4fcbc51e9da1666eca12bb125c08789d0fde099f56d421e8ad32d41ca85b
# ✅ Data Stored: temperature - 2.41, Txn Hash: 78765aad58490ca19d65785af94d272b5d122e201b37ac4d1e95e85a60a5e7de
# ✅ Data Stored: temperature - 8.28, Txn Hash: e8d081027106ebd62e4844bbf06e7e294e708b07bf8b253d8ff2c71a64d5afef
# ✅ Data Stored: temperature - 8.34, Txn Hash: d28567fd547590fe214dbbf8090553466b0ebb07805bf2a5785ba3c79994bf0e
# ✅ Data Stored: temperature - 8.74, Txn Hash: 5b2ee23f3b2f5790c8c7b1a1c8041c5a850113788572005c468d7aecc55488bb
# ✅ Data Stored: temperature - 2.04, Txn Hash: 02e9ac08ba28a5479739f2b0738d116ecde96d5375fed667927fefe8d6a7b3bd
# ✅ Data Stored: temperature - 9.05, Txn Hash: d34c3ed702002a618ea6594a47ac301723ff62fed0c1e052c57878947c8e5a9d
# ✅ Data Stored: temperature - 4.54, Txn Hash: ab39aaedb74483f6d7eec3a14ee3d547201e295c3c9309b26940229d8b4379a5
# ✅ Data Stored: temperature - 7.02, Txn Hash: 2061869bd14a5c1fb5a99121478f91c110af76c700e7cf078914b7d688af6203
# ✅ Data Stored: temperature - 5.08, Txn Hash: 26c1be6b735a95550dcb06c409b91d4044132c887245efbe426d4422933d9318
# ✅ Data Stored: temperature - 3.85, Txn Hash: 1bead5f8b4cffdbdd6026420b4482c12468a59ab9100d20d856b6d775e5d749a
# ✅ Data Stored: temperature - 7.76, Txn Hash: c51e4e1ee2331ba6540fd4dab6c0111320d6b8e6bc6ef79bdf775af091626588
# ✅ Data Stored: temperature - 8.06, Txn Hash: ec6e17bb2619d9dce4703d0638c3d1e7eca483fc2ae068267649e33415ea93ab
# ✅ Data Stored: temperature - 9.54, Txn Hash: 9391ae1ced048b42b2f7e7b11f8a93f2d328a8924e55ce05ffe94d7ab4a856a1
# ✅ Data Stored: temperature - 8.0, Txn Hash: b4feb084881cbc986c8b8692355783351c2ee1d9a90228656e1cb8965319555a
# ✅ Data Stored: temperature - 2.13, Txn Hash: c5e26b3a07c01a2b056bd5ccc1da979c7813d56b78e1e388110ba66bd949c6da
# ✅ Data Stored: temperature - 8.54, Txn Hash: fbef7920b5d0a7d78852b613556202bb96356d7a9bcf34a3a9cb9564298e20be
# ✅ Data Stored: temperature - 8.97, Txn Hash: 40908d238d320e372575ea729365ed5dede177c87f205465a2dcbc2c37c581fa
# ✅ Data Stored: temperature - 2.76, Txn Hash: 85e983cd1d80cb3f4fc6e5953090d0391fd09e346dbee537d6027c976ce9687f
# ✅ Data Stored: temperature - 9.79, Txn Hash: 67964918ab546f176fbb3efdd1da4706ea738df26c7f755092dd4e64c82fb15a
# ✅ Data Stored: temperature - 6.67, Txn Hash: a9232f4b6a1df1b71b6ffed8da2d0738f3d38fed492d4a2dd26c1534ed16c71d
# ✅ Data Stored: temperature - 6.42, Txn Hash: e78f9487e1ec2cc54d34cc53c247d554330c76f6afa3601e6ab38d76880c06d1
# ✅ Data Stored: temperature - 8.32, Txn Hash: daf455fdd9e2b8ff6c96a7b700989a1535232ff66ca3ed7316aac577aecb709f
# ✅ Data Stored: temperature - 5.35, Txn Hash: a8db51fd75eb4ba7211fbd9b258eab8d2d27a516deb587742f5a9e3335f1e252
# ✅ Data Stored: temperature - 8.7, Txn Hash: dd12b11ec7bbe0b2acc082bc0153d8f3eeecaff148f3a806f4d0aa9c31fae04a
# ✅ Data Stored: temperature - 2.04, Txn Hash: e035ef1ff421f60c756ff7e818f9fe55ee47775e79738323f297ffb14b093471
# ✅ Data Stored: temperature - 3.17, Txn Hash: 6fdd4805970fb5c6e68d4eedf56b3340929f82c86399731d034bf5d6f34a1cab
# ✅ Data Stored: temperature - 2.9, Txn Hash: a4e27cd6cb0d5f1c28f8f0b1ba9fd8fdebc3c34081c21fb36b841723cc5ce642
# ✅ Data Stored: temperature - 6.94, Txn Hash: 31539d0b70e4d0a28a699eb7989f2a22f6e1cff63de419c180d0e73657c4edc7
# ✅ Data Stored: temperature - 2.46, Txn Hash: 5c88c4ad7a4e6440a3bc8a29eb4e2b6590138b0de5dd3b22662ed2fd72b11b9a
# ✅ Data Stored: temperature - 4.69, Txn Hash: 90765471f6e536c5f4788c5fb761bc3cba9cc9bd5dcd84cc72ec192fbc65e123
# ✅ Data Stored: temperature - 3.73, Txn Hash: 7eac36aa1b14c0d6141386f1004546b3bd8bebc587c1114e2a09708fc162b2ba
# ✅ Data Stored: temperature - 8.85, Txn Hash: f9b951ce22235ace917fb789a2aa94216b78d20f1bf5e5acad3eed1325f4c4ce
# ✅ Data Stored: temperature - 7.2, Txn Hash: af58a9c0059ed4ce0d71f37f5aa6a2714e94c890cd01a0bf4cb3bc1f3fd6bc71
# ✅ Data Stored: temperature - 6.07, Txn Hash: 919b1a2f074c8624fab6711109354fbb1423fda665a77b08d9fb6415de858f89
# ✅ Data Stored: temperature - 5.9, Txn Hash: b3e8fc9370abd158c3fd04b368e8edd45ccd3d9c82eca4555f499cf5ce8123fb
# ✅ Data Stored: temperature - 7.64, Txn Hash: 2512f82db9d6532dfd972693eb0639a19f4e6c1846a38b776f53e9a4a1f0e58c
# ✅ Data Stored: temperature - 3.12, Txn Hash: 691725bd889a1e94dfc0b96fca6bbe49269bc8d66bba249a36e3d0213103f7a3
# ✅ Data Stored: temperature - 8.98, Txn Hash: eb35017ab502df4b82fb899ee2188f50cb7d84146f19c8d844cc6d2ad3080b8c
# ✅ Data Stored: temperature - 6.35, Txn Hash: 9e2fac2004c5892dd69d3dbd64b5e7873b89afa207ade1bb5cb1e03454050d55
# ✅ Data Stored: temperature - 6.07, Txn Hash: fc31497685344c25c0b2c824d17aed5082d9f63ed53329c78980da6cd7b36d4b
# ✅ Data Stored: temperature - 3.72, Txn Hash: 9581abb8c882c6f3cae26f4adc9d572088c45192c8eb4fbe7354a7c8f609b332
# ✅ Data Stored: temperature - 9.41, Txn Hash: 6517b809496fa02fb4869c5a78a1a1a881df26907e5e4f72dd4544ce3062d5f8
# ✅ Data Stored: temperature - 5.12, Txn Hash: 6166ed87943325a124d18ef2924115f8339d61d7a41f7cff0796ad16aee4399a
# ✅ Data Stored: temperature - 3.15, Txn Hash: 22059c406cf790d7fa53246d66a5fcdeca6a9b60d3dd9750fa3842a5168168ef
# ✅ Data Stored: temperature - 5.46, Txn Hash: e3e1f3ca22b3434d6ba9f941e302f644c610a7649f4a893a8f9c0db02440131f
# ✅ Data Stored: temperature - 3.67, Txn Hash: 1aed4c4ba951e6c36794577515fe6e51f97ae398494670c0088602569f1e89ea
# ✅ Data Stored: temperature - 2.34, Txn Hash: dcdb9ffaaee6139cbeb6a7e3c110fee80c5bc1a296231331e8cf5ee73fd4760b
# ✅ Data Stored: temperature - 7.09, Txn Hash: f12d274f7d1783486466c4245b66d6dfad1d9d6fec87acc1b883ca06c58dc389
# ✅ Data Stored: temperature - 8.53, Txn Hash: 34fc282cb0947c9b19dba28fdfe3c2476288490204535197f5af5bb0daf131f4
# ❌ Failed to retrieve records: Could not transact with/call contract function, is contract deployed correctly and chain synced?
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
