# %%
import pandas as pd

# Load IoT sensor data from CSV (Generated in Homework 1)
df = pd.read_csv("resources/smart_logistics_data.csv")

# Display the first few rows
print(df.head())
# Out:
#   shipment_id                   timestamp    gps_lat    gps_long  rfid_tag  \
# 0   SHP980988  2025-05-15 13:52:59.194834  11.721861  122.739816  RFID1098
# 1   SHP650973  2025-05-15 07:19:59.194993  13.051399  121.518155  RFID1063
# 2   SHP339067  2025-05-15 05:03:59.195050  13.867232  122.339907  RFID1010
# 3   SHP328994  2025-05-15 20:11:59.195101  14.814776  122.012883  RFID1096
# 4   SHP634775  2025-05-15 15:02:59.195151  10.127991  120.478309  RFID1037
#
#    package_temp_c  humidity_percent            status
# 0            6.80             43.68        In Transit
# 1            9.49             59.35    Arrived at Hub
# 2            6.63             34.58           Delayed
# 3            9.23             30.99           Delayed
# 4            8.04             46.65  Out for Delivery

# %%
from web3 import Web3


# Connect to local blockchain
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))


# Verify connection
if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
# Out:
# ✅ Connected to Ganache successfully!

# %%
# Convert the contract address to checksum format
contract_address = Web3.to_checksum_address("0x5242bfea733394a24f7ada732c8a8120abb443be")

# Set the default account (convert if necessary)
web3.eth.default_account = Web3.to_checksum_address("0xbB3Bd5F65411fddbaCdEaFeD0c95163cf0221376")

abi = [
    {
        "inputs": [],
        "stateMutability": "nonpayable",
        "type": "constructor"
    },
    {
        "anonymous": False,
        "inputs": [
            {
                "indexed": False,
                "internalType": "uint256",
                "name": "timestamp",
                "type": "uint256"
            },
            {
                "indexed": False,
                "internalType": "string",
                "name": "deviceId",
                "type": "string"
            },
            {
                "indexed": False,
                "internalType": "string",
                "name": "dataType",
                "type": "string"
            },
            {
                "indexed": False,
                "internalType": "string",
                "name": "dataValue",
                "type": "string"
            }
        ],
        "name": "IoTDataStored",
        "type": "event"
    },
    {
        "anonymous": False,
        "inputs": [
            {
                "indexed": True,
                "internalType": "string",
                "name": "packageId",
                "type": "string"
            },
            {
                "indexed": True,
                "internalType": "string",
                "name": "dataType",
                "type": "string"
            },
            {
                "indexed": False,
                "internalType": "string",
                "name": "value",
                "type": "string"
            }
        ],
        "name": "PackageDataStored",
        "type": "event"
    },
    {
        "inputs": [],
        "name": "populateWithSamplePackageData",
        "outputs": [],
        "stateMutability": "nonpayable",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "string",
                "name": "packageId",
                "type": "string"
            }
        ],
        "name": "resetPackageData",
        "outputs": [],
        "stateMutability": "nonpayable",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "string",
                "name": "deviceId",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "dataType",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "dataValue",
                "type": "string"
            }
        ],
        "name": "storeIoTData",
        "outputs": [],
        "stateMutability": "nonpayable",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "string",
                "name": "packageId",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "dataType",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "value",
                "type": "string"
            }
        ],
        "name": "storePackageData",
        "outputs": [],
        "stateMutability": "nonpayable",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "uint256",
                "name": "index",
                "type": "uint256"
            }
        ],
        "name": "getIoTRecord",
        "outputs": [
            {
                "internalType": "uint256",
                "name": "",
                "type": "uint256"
            },
            {
                "internalType": "string",
                "name": "",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "",
                "type": "string"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "string",
                "name": "packageId",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "dataType",
                "type": "string"
            }
        ],
        "name": "getPackageData",
        "outputs": [
            {
                "internalType": "string",
                "name": "",
                "type": "string"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [],
        "name": "getTotalIoTRecords",
        "outputs": [
            {
                "internalType": "uint256",
                "name": "",
                "type": "uint256"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "uint256",
                "name": "",
                "type": "uint256"
            }
        ],
        "name": "iotDataRecords",
        "outputs": [
            {
                "internalType": "uint256",
                "name": "timestamp",
                "type": "uint256"
            },
            {
                "internalType": "string",
                "name": "deviceId",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "dataType",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "dataValue",
                "type": "string"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [],
        "name": "MAX_IOT_ENTRIES",
        "outputs": [
            {
                "internalType": "uint256",
                "name": "",
                "type": "uint256"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [],
        "name": "owner",
        "outputs": [
            {
                "internalType": "address",
                "name": "",
                "type": "address"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    }
]


# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)


# Set default sender (first account from Ganache)
web3.eth.default_account = web3.eth.accounts[0]

print(f"✅ Connected to Smart Contract at {contract_address}")
# Out:
# ✅ Connected to Smart Contract at 0x5242BfEa733394A24F7AdA732C8a8120abb443Be

# %%
import time

def send_iot_data(device_id, data_type, data_value):
    """
    Sends IoT data to the deployed smart contract.
    """
    try:
        # Create and send the transaction
        txn = contract.functions.storeIoTData(device_id, data_type, data_value).transact({
            'from': web3.eth.default_account,
            'gas': 3000000
        })
        # Wait for the transaction receipt
        receipt = web3.eth.wait_for_transaction_receipt(txn)
        print(f"✅ Data Stored: {data_type} - {data_value}, Txn Hash: {receipt.transactionHash.hex()}")
    except Exception as e:
        print(f"❌ Failed to store data: {e}")

# Debugging: Ensure the DataFrame is loaded correctly
print(f"Number of records in the CSV: {len(df)}")
print("Preview of the DataFrame:")
print(df.head())

# Loop through the DataFrame and send each row to the blockchain
print("🚀 Sending IoT data to the blockchain...")
for index, row in df.iterrows():
    print(f"Processing row {index + 1}/{len(df)}: {row['rfid_tag']}, {row['package_temp_c']}")
    send_iot_data(
        str(row["rfid_tag"]),  # Replace with the correct column name if different
        "temperature",
        str(row["package_temp_c"])  # Replace with the correct column name if different
    )
    time.sleep(1)  # Delay to prevent flooding transactions

# Retrieve and verify storage
try:
    total_records = contract.functions.getTotalIoTRecords().call()
    print(f"📊 Total IoT records stored: {total_records}")

    # Retrieve and print the first stored record
    if total_records > 0:
        record = contract.functions.getIoTRecord(0).call()
        print("📄 First Stored Record:", record)
    else:
        print("⚠️ No records found on the blockchain.")
except Exception as e:
    print(f"❌ Failed to retrieve records: {e}")
# Out:
# Number of records in the CSV: 100
# Preview of the DataFrame:
#   shipment_id                   timestamp    gps_lat    gps_long  rfid_tag  \
# 0   SHP980988  2025-05-15 13:52:59.194834  11.721861  122.739816  RFID1098
# 1   SHP650973  2025-05-15 07:19:59.194993  13.051399  121.518155  RFID1063
# 2   SHP339067  2025-05-15 05:03:59.195050  13.867232  122.339907  RFID1010
# 3   SHP328994  2025-05-15 20:11:59.195101  14.814776  122.012883  RFID1096
# 4   SHP634775  2025-05-15 15:02:59.195151  10.127991  120.478309  RFID1037
#
#    package_temp_c  humidity_percent            status
# 0            6.80             43.68        In Transit
# 1            9.49             59.35    Arrived at Hub
# 2            6.63             34.58           Delayed
# 3            9.23             30.99           Delayed
# 4            8.04             46.65  Out for Delivery
# 🚀 Sending IoT data to the blockchain...
# Processing row 1/100: RFID1098, 6.8
# ✅ Data Stored: temperature - 6.8, Txn Hash: 1ebe3432ea046df644f41e899b7209a734b02f058b2529e5e90f50bbc57ac3dd
# Processing row 2/100: RFID1063, 9.49
# ✅ Data Stored: temperature - 9.49, Txn Hash: df33ba98f5d95b3b0163cc3dcfa66432a836f8b164bd7e7f23d973fce86a689f
# Processing row 3/100: RFID1010, 6.63
# ✅ Data Stored: temperature - 6.63, Txn Hash: 114bed16a1d39d622c2a708c067d737f753645d530c6ed374952ff47e4cec926
# Processing row 4/100: RFID1096, 9.23
# ✅ Data Stored: temperature - 9.23, Txn Hash: 086347a4ba05cb95fc69e1a9729cbe4212ab727a7f5cd34c4b0ff9382b44aa30
# Processing row 5/100: RFID1037, 8.04
# ✅ Data Stored: temperature - 8.04, Txn Hash: 4530ebe63fae323087bd11abcece90f99d716fbe503d202921123c07cb61a486
# Processing row 6/100: RFID1031, 5.89
# ✅ Data Stored: temperature - 5.89, Txn Hash: 7df29abc6775b9fa4e00ab2df16a56194f55b076a16465784615fa7f07bc0f0e
# Processing row 7/100: RFID1012, 6.94
# ✅ Data Stored: temperature - 6.94, Txn Hash: 769fe06674afc9d784c806f13641e2b60a1e99d4aeedd6c96821f3757aef6db6
# Processing row 8/100: RFID1069, 2.59
# ✅ Data Stored: temperature - 2.59, Txn Hash: 329303b547da3375e73e49645b4ec3399c1e042fe2c54298ae7b512dcaaf99ea
# Processing row 9/100: RFID1026, 3.49
# ✅ Data Stored: temperature - 3.49, Txn Hash: 5b848c06bab87b75a9e62a701620315a18e7b09205a583915e00758022d6cbf2
# Processing row 10/100: RFID1085, 3.43
# ✅ Data Stored: temperature - 3.43, Txn Hash: 77cfca7eb5d95dcb3596f9e32d01ba8aa26b6158f2339cb8edd37e9f7b6ced18
# Processing row 11/100: RFID1048, 4.12
# ✅ Data Stored: temperature - 4.12, Txn Hash: e0c5e332429fd95a12937c52ccd388fd4695192738241666d4e5db2582ee939c
# Processing row 12/100: RFID1083, 3.8
# ✅ Data Stored: temperature - 3.8, Txn Hash: e6e6b98b3818890927038d17d7e2b4949412a79fee0973fd2c98ca5fdc3e2d6c
# Processing row 13/100: RFID1075, 3.61
# ✅ Data Stored: temperature - 3.61, Txn Hash: 684e0ceec30a8413ec8355eddd84092aeb55a0b98b55222601448e49c52afb85
# Processing row 14/100: RFID1085, 7.19
# ✅ Data Stored: temperature - 7.19, Txn Hash: b559a0411d5f4b5da3ec575578b8d73fd96f35ba66142f3a3dc35acbd7c5faf5
# Processing row 15/100: RFID1034, 6.84
# ✅ Data Stored: temperature - 6.84, Txn Hash: 8f2b0e2055cef9f1a22a64b0d790e8b2539d43a957a33ca8ef7f5b7f2f4aa88d
# Processing row 16/100: RFID1059, 4.38
# ✅ Data Stored: temperature - 4.38, Txn Hash: 75c261318a7508cfb8bb52fa047683d86facd622656b80a578d64572bfc5d4f6
# Processing row 17/100: RFID1036, 7.9
# ✅ Data Stored: temperature - 7.9, Txn Hash: 93a5fc82fd389083c2b7957b85b222eb1e28200c54141cbf565195fd47bb4caf
# Processing row 18/100: RFID1089, 2.6
# ✅ Data Stored: temperature - 2.6, Txn Hash: 883121a23796671bd4110df25d9ea2725a6935a7f8855409c3635891bdcd25f7
# Processing row 19/100: RFID1005, 5.31
# ✅ Data Stored: temperature - 5.31, Txn Hash: 341908d7b86f0d7fd1aa0fe0913fd6724af7305cad12fbb2e68e43b553ebe112
# Processing row 20/100: RFID1054, 4.34
# ✅ Data Stored: temperature - 4.34, Txn Hash: add5ca57d112196d0fcf23fd31962e77cdcbcf5a99b06cdc1244b9d504a41a2a
# Processing row 21/100: RFID1091, 5.34
# ✅ Data Stored: temperature - 5.34, Txn Hash: 7b3e7c163ca19d36b6d9c132234a8b15a05db5800705edbb112b038846d9ed98
# Processing row 22/100: RFID1028, 7.2
# ✅ Data Stored: temperature - 7.2, Txn Hash: a092905e0723c07463c4dcc141e79a601d8f2f8d8edb8889e774e086a48c7465
# Processing row 23/100: RFID1084, 7.38
# ✅ Data Stored: temperature - 7.38, Txn Hash: 00aa1dd949a7042bc0ae42b1f0342420721d28ee4277ea9270d38f0a93c332c2
# Processing row 24/100: RFID1073, 7.58
# ✅ Data Stored: temperature - 7.58, Txn Hash: 79f7b93098ecc41063f217e0ffc8cbdd7895f8d321ef4ac9d2090f48b4b4fbe8
# Processing row 25/100: RFID1085, 3.82
# ✅ Data Stored: temperature - 3.82, Txn Hash: 1a6a8248a016ead075297a49ac2e2ef387070c58e3d404f7ad78ac9eab47e127
# Processing row 26/100: RFID1046, 3.3
# ✅ Data Stored: temperature - 3.3, Txn Hash: 5eee1730b50dc1ac324b16e8c6afdef03a750fdec2e4d1eb42c570e0ba8860d6
# Processing row 27/100: RFID1034, 6.55
# ✅ Data Stored: temperature - 6.55, Txn Hash: 6fd1dce01a18aa0fc323d638724a9d9e887ac7c4926fa52d7d3d1f8748a29576
# Processing row 28/100: RFID1022, 9.29
# ✅ Data Stored: temperature - 9.29, Txn Hash: eca92d087ce5bbb92a4eaa3f62fad28ae7e3ad73843572e6540f5e83b88fc47d
# Processing row 29/100: RFID1049, 6.38
# ✅ Data Stored: temperature - 6.38, Txn Hash: 77cc0d96b461e86a8d08ca350006c231e2720054d8fb827a4db1797be45bce9c
# Processing row 30/100: RFID1070, 5.62
# ✅ Data Stored: temperature - 5.62, Txn Hash: 2597c19fc12909f88082b98ca465b167c111b7ff863a6acbeeed794e5bcdfd69
# Processing row 31/100: RFID1009, 2.31
# ✅ Data Stored: temperature - 2.31, Txn Hash: a306204265bf647a0a2f037dbde3f0fb69ecbb93695bbcbb5a3658dce59eb67f
# Processing row 32/100: RFID1065, 6.83
# ✅ Data Stored: temperature - 6.83, Txn Hash: 5ae5d13bfd2e83ab80d18d07e751fbdd581c3bc11d0e73c37714fb6f25f60816
# Processing row 33/100: RFID1056, 3.91
# ✅ Data Stored: temperature - 3.91, Txn Hash: 41d06094441517640a2a9da8721d434980193780d0a3f1303f90c2bcbcc511c3
# Processing row 34/100: RFID1083, 8.08
# ✅ Data Stored: temperature - 8.08, Txn Hash: f2e4c8940c8c267ce205fd71361d76a894c00877294a7f6f13f30d5a201061b2
# Processing row 35/100: RFID1073, 5.01
# ✅ Data Stored: temperature - 5.01, Txn Hash: d1bb2e57ac8afea6d7a2dc3888e4a80cff388061a448af9241a00b5148811eb0
# Processing row 36/100: RFID1049, 8.88
# ✅ Data Stored: temperature - 8.88, Txn Hash: 9397bd8bcc8a2f9240bba6815b30d6a5b28c85a79623a6ca2b5e7ac8865b0702
# Processing row 37/100: RFID1099, 5.81
# ✅ Data Stored: temperature - 5.81, Txn Hash: 29dbdc376631ff4e3c19ed3b5166787f210cf28b273f3ced263ae2e7e383e10c
# Processing row 38/100: RFID1081, 5.31
# ✅ Data Stored: temperature - 5.31, Txn Hash: 126284f1fdaf7dc6f330e15ef832d5bcf5b3c341aea7f61f2b8b7ffaf3210304
# Processing row 39/100: RFID1043, 5.21
# ✅ Data Stored: temperature - 5.21, Txn Hash: fdf7e0295604510541b7cae838414aab50efb16413b5c056296b68fc6a435eea
# Processing row 40/100: RFID1075, 9.72
# ✅ Data Stored: temperature - 9.72, Txn Hash: 34c03d0f7a6abdd6dd34624d267aed09940c02d1468f1742b4bb0a7441c7fff9
# Processing row 41/100: RFID1032, 3.65
# ✅ Data Stored: temperature - 3.65, Txn Hash: 1fcc280f4d53c7d0728f61608ae322f27a8900ad11ad91d28b60fa135cfb32ec
# Processing row 42/100: RFID1026, 7.76
# ✅ Data Stored: temperature - 7.76, Txn Hash: bfcb01a087853ed864f48e5280d4701ed2a17cc6cdcc3565c490c235c8cadafe
# Processing row 43/100: RFID1034, 4.29
# ✅ Data Stored: temperature - 4.29, Txn Hash: c0dbe2073d244263ac7bd94cdfecf31b1b33492210c811188bd4e729afb15882
# Processing row 44/100: RFID1066, 3.67
# ✅ Data Stored: temperature - 3.67, Txn Hash: 7dd90e3df7598a6285c2c2ffc6d9fa091865cf86da5e33fdedbff2cf144889eb
# Processing row 45/100: RFID1057, 5.79
# ✅ Data Stored: temperature - 5.79, Txn Hash: b38565231668825d26e50c16a913d33e71f26912aa7d929f41ba44627586299b
# Processing row 46/100: RFID1043, 5.33
# ✅ Data Stored: temperature - 5.33, Txn Hash: 15c314e18b36b304c2b694226b403db4a6fb0f5ea063f8d7ae3ff43d131cc6f0
# Processing row 47/100: RFID1018, 4.63
# ✅ Data Stored: temperature - 4.63, Txn Hash: 4bf21fb632c9afcc255ae3b7f9c6140c63e1dce14f1a01da19c12cc379a65b36
# Processing row 48/100: RFID1002, 7.3
# ✅ Data Stored: temperature - 7.3, Txn Hash: b56a39c0d9fdfba41a4b4cfb958fb1f473791b60580e2eb01bb2c7a3b7207b2f
# Processing row 49/100: RFID1037, 5.2
# ✅ Data Stored: temperature - 5.2, Txn Hash: ecce917140e4414b14ea97b46807367961522ce886657f7885ee3c4c5a51fb2a
# Processing row 50/100: RFID1011, 7.26
# ✅ Data Stored: temperature - 7.26, Txn Hash: 474ba6c3d4ba8043707f6d03af5566803ad5fbea74853d3f8d8fc6de5ab4856b
# Processing row 51/100: RFID1056, 6.86
# ✅ Data Stored: temperature - 6.86, Txn Hash: 4a4b250a4c1a64b2e04f1db590088c0fd16e0ad60717031a2ad57aef85e4cd74
# Processing row 52/100: RFID1092, 2.41
# ✅ Data Stored: temperature - 2.41, Txn Hash: 26a75cee119234b00e2c8353b2d64ed85ae47d8eb679f71e57fc2d188bb326a1
# Processing row 53/100: RFID1009, 8.28
# ✅ Data Stored: temperature - 8.28, Txn Hash: 68267088ef300cb530b385471a9ffb69ae4bb7001f9f7d93b38a5a327473a858
# Processing row 54/100: RFID1091, 8.34
# ✅ Data Stored: temperature - 8.34, Txn Hash: 097f318dab9ad8ac7c45c300b66cae3c7d1c100f74e95ae66153baadb5178e04
# Processing row 55/100: RFID1048, 8.74
# ✅ Data Stored: temperature - 8.74, Txn Hash: 43a14b1c26a5dcc5300086c08a1e9af897b99a587b026eedee0442f113b670d8
# Processing row 56/100: RFID1025, 2.04
# ✅ Data Stored: temperature - 2.04, Txn Hash: 6446e0b911126bb3ffe0a09e0054905c17366f5c7b3f53f86a59c86169252b41
# Processing row 57/100: RFID1042, 9.05
# ✅ Data Stored: temperature - 9.05, Txn Hash: 9f3759657ea76d8a49641e04542e257fa749c75652813bbf219067549e5cdc88
# Processing row 58/100: RFID1070, 4.54
# ✅ Data Stored: temperature - 4.54, Txn Hash: c81c19c7733ca95039a06b6f905ca75b608cd2a0889a4ab9fc5b421ed677b5b2
# Processing row 59/100: RFID1081, 7.02
# ✅ Data Stored: temperature - 7.02, Txn Hash: 76403d176192699dca82237df2b241cf62c4e99ccd59d175adeb752885eefb46
# Processing row 60/100: RFID1052, 5.08
# ✅ Data Stored: temperature - 5.08, Txn Hash: eea09fdef06ba8994a47faf4e3dd33346d2d4f6390f0eb5e02467622ea7834d4
# Processing row 61/100: RFID1051, 3.85
# ✅ Data Stored: temperature - 3.85, Txn Hash: 04442aef3685bbd3dc7a795ce85a2a3e81da643aabf5cbcac83b8295b5018e7c
# Processing row 62/100: RFID1063, 7.76
# ✅ Data Stored: temperature - 7.76, Txn Hash: 87f61e23ef3347e0a0efa9c3ee63b1290378aafa3a519987c33dfb17d1bb85ff
# Processing row 63/100: RFID1039, 8.06
# ✅ Data Stored: temperature - 8.06, Txn Hash: 4bab595687584d5b1fe5e02002d6111e444d505631d7f0d7c3eaa0e34260c781
# Processing row 64/100: RFID1073, 9.54
# ✅ Data Stored: temperature - 9.54, Txn Hash: 08546ba20d9beb4dc1762194b8e14420593b733a6ea9f6eb7d13d67c195dedba
# Processing row 65/100: RFID1070, 8.0
# ✅ Data Stored: temperature - 8.0, Txn Hash: fb6d8ef67622849d0817a4164d6e46422c0aa54fb2b0d15743f90c1a34e4d8aa
# Processing row 66/100: RFID1083, 2.13
# ✅ Data Stored: temperature - 2.13, Txn Hash: 4828be8e2da48431f3ba62cff6b50721f4efe0915a560cf31d7280685da68da0
# Processing row 67/100: RFID1000, 8.54
# ✅ Data Stored: temperature - 8.54, Txn Hash: 4a00a5351ec3456f96f7a458079d2b2ce5e66a8215cc9bc0181750f1a0a7dae1
# Processing row 68/100: RFID1070, 8.97
# ✅ Data Stored: temperature - 8.97, Txn Hash: fce1e757319c9a9298de2a63201a33f701cda88dd83e88793736e2cec8fd63a4
# Processing row 69/100: RFID1039, 2.76
# ✅ Data Stored: temperature - 2.76, Txn Hash: 3686339866e86a3fd03521999402b21f7c5884d44cba186b301fc4b994c40369
# Processing row 70/100: RFID1002, 9.79
# ✅ Data Stored: temperature - 9.79, Txn Hash: 3dcdb722930da898a46e7ec91413a5a03a4760a88233acfdf6a07b0d83aae7e4
# Processing row 71/100: RFID1048, 6.67
# ✅ Data Stored: temperature - 6.67, Txn Hash: f36f381847d70c624f9fa3d9c906ea541da20da9e5e0ead53288c8ad7a6b9fa8
# Processing row 72/100: RFID1073, 6.42
# ✅ Data Stored: temperature - 6.42, Txn Hash: 0704a9d81904897d7144c59f49c8658cadbfb4493c9c0daa6faf94d4fae01c26
# Processing row 73/100: RFID1017, 8.32
# ✅ Data Stored: temperature - 8.32, Txn Hash: 7ec39110f512f348e329bd4d9968009775d76c23df3a44baabb60d6d22f8745e
# Processing row 74/100: RFID1065, 5.35
# ✅ Data Stored: temperature - 5.35, Txn Hash: f866591c44e2bfd72df9eb5f0d66a388187d6eebd6c3b4339d958205923bd27f
# Processing row 75/100: RFID1066, 8.7
# ✅ Data Stored: temperature - 8.7, Txn Hash: 0cb22f7e66bc3d04337809e8916b51de3fb00ff0f916d513ecbce106684a371e
# Processing row 76/100: RFID1004, 2.04
# ✅ Data Stored: temperature - 2.04, Txn Hash: e2e218b67f2212f0eef6f68241486965224a70529ac5fb9d7731ea6d670ef053
# Processing row 77/100: RFID1065, 3.17
# ✅ Data Stored: temperature - 3.17, Txn Hash: dcf95112f906c682f024cd1ad20748222468b7e3244c5122e43e7099163b36a8
# Processing row 78/100: RFID1018, 2.9
# ✅ Data Stored: temperature - 2.9, Txn Hash: f2618ffa2e73276e097e75c75db472f98493522b7ca421891ad86020d71d4af0
# Processing row 79/100: RFID1016, 6.94
# ✅ Data Stored: temperature - 6.94, Txn Hash: 45316c907175b09ab9cfee4fac5e74b3bff1440c1dc0b9e69b5cd3d3655a5e3e
# Processing row 80/100: RFID1044, 2.46
# ✅ Data Stored: temperature - 2.46, Txn Hash: fd944579621df38708fff09fa8260f2d5036665b3f5295c3c58dcb9eb47fff86
# Processing row 81/100: RFID1098, 4.69
# ✅ Data Stored: temperature - 4.69, Txn Hash: cd80215bb83cc7565c4e42c594d4c124f465aa2086509463cff3de7a2b07f3f6
# Processing row 82/100: RFID1026, 3.73
# ✅ Data Stored: temperature - 3.73, Txn Hash: 12fe0f7358acfb8a6a74db8dd39c6f21665fdf1eba3acf09877981221569f152
# Processing row 83/100: RFID1030, 8.85
# ✅ Data Stored: temperature - 8.85, Txn Hash: baed4365d2cd41a95583767ba82a666537f65ce0266f7305ab693aaeb28fcbf7
# Processing row 84/100: RFID1069, 7.2
# ✅ Data Stored: temperature - 7.2, Txn Hash: 984119a02be73d533371f8ed3d49a9aa4ffe1726e180b8350b237f87e5637a3d
# Processing row 85/100: RFID1096, 6.07
# ✅ Data Stored: temperature - 6.07, Txn Hash: 4ce45914d7a11469ef51ed8842a20c4539844be027fbdd04e1b2571cf1733ac8
# Processing row 86/100: RFID1043, 5.9
# ✅ Data Stored: temperature - 5.9, Txn Hash: e66a37e03d5c357d2e646d018a4f2731ef12d6a06f1fd6349e4b49a4953ceb6a
# Processing row 87/100: RFID1074, 7.64
# ✅ Data Stored: temperature - 7.64, Txn Hash: 948035d687a6e8ded7a14a7dcfbf7a33b888c93d993bb15cc3ff3b33bc36709c
# Processing row 88/100: RFID1054, 3.12
# ✅ Data Stored: temperature - 3.12, Txn Hash: 538d8a6e80e8c9ba7dfcad224f68c45a42393cc560895c31af2380a407178cce
# Processing row 89/100: RFID1037, 8.98
# ✅ Data Stored: temperature - 8.98, Txn Hash: bbcf2af2ca63962ba7007f43967fecbfdfa09c4b779bc4524dd45b5ef640cacd
# Processing row 90/100: RFID1059, 6.35
# ✅ Data Stored: temperature - 6.35, Txn Hash: 353b588093f707aea85cd28b97212866a427eb6d661a7a0ef96d9b0e3aa14d6e
# Processing row 91/100: RFID1015, 6.07
# ✅ Data Stored: temperature - 6.07, Txn Hash: 14be4eb192b8367c0db6aedf05cbb254ad3fdc7af3c88077dccfd316ff53f558
# Processing row 92/100: RFID1012, 3.72
# ✅ Data Stored: temperature - 3.72, Txn Hash: ea6cf8192eea1ac747564a21add299819cd426d53e6ea19c2a09288925bcd8ff
# Processing row 93/100: RFID1014, 9.41
# ✅ Data Stored: temperature - 9.41, Txn Hash: 77f167c509a33fd738b2d50cca7c3358bbf81eadc19b9546257d4e164c8d1e7f
# Processing row 94/100: RFID1062, 5.12
# ✅ Data Stored: temperature - 5.12, Txn Hash: b817332e580114d71193b0bb6cf7d291e97b1025fac606efc6dc91c2a9359039
# Processing row 95/100: RFID1042, 3.15
# ✅ Data Stored: temperature - 3.15, Txn Hash: 8482f3a47194a8c82d8afac97a5a30e9ecd5a5693776a87290d38ad65aaf75e4
# Processing row 96/100: RFID1071, 5.46
# ✅ Data Stored: temperature - 5.46, Txn Hash: e6941c8ca5e148b8d95a72c6a1783c2621ddc1d59ceb7313b0fe9399c4f517e3
# Processing row 97/100: RFID1051, 3.67
# ✅ Data Stored: temperature - 3.67, Txn Hash: f4b627e2cfeab948f791d589df2914aaba62adc40321daf8026e41ad9052281d
# Processing row 98/100: RFID1004, 2.34
# ✅ Data Stored: temperature - 2.34, Txn Hash: bb1f39fc58e5fe4f99b4fd55dbc9baa32a51520e8eaf9f1999038c423104a0dd
# Processing row 99/100: RFID1022, 7.09
# ✅ Data Stored: temperature - 7.09, Txn Hash: 4f1e5b9f699edd067b975591992eadaf4102824179b0f4cf41de7ae92224f83f
# Processing row 100/100: RFID1061, 8.53
# ✅ Data Stored: temperature - 8.53, Txn Hash: 2b595b4503a0e9fa978b4fc08e65fa462391be78402eccf2cfc34dc27b69cdaa
# 📊 Total IoT records stored: 100
# 📄 First Stored Record: [1747568299, 'RFID1098', 'temperature', '6.8']

# %%
# Retrieve and verify storage
try:
    total_records = contract.functions.getTotalIoTRecords().call()
    print(f"📊 Total IoT records stored: {total_records}")

    # Retrieve and print the first stored record
    if total_records > 0:
        record = contract.functions.getIoTRecord(0).call()
        print("🔹 First stored record retrieved from blockchain:")
        print(f"Timestamp: {record[0]}")
        print(f"Device ID: {record[1]}")
        print(f"Data Type: {record[2]}")
        print(f"Data Value: {record[3]}")
    else:
        print("⚠️ No records found on the blockchain.")
except Exception as e:
    print(f"❌ Failed to retrieve records: {e}")
# Out:
# 📊 Total IoT records stored: 100
# 🔹 First stored record retrieved from blockchain:
# Timestamp: 1747568299
# Device ID: RFID1098
# Data Type: temperature
# Data Value: 6.8
