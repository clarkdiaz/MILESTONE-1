# %%
import pandas as pd
from web3 import Web3
import time

# Step 1: Load CSV
df = pd.read_csv("resources/smart_logistics_data.csv")
print("🧾 Columns in CSV:", df.columns.tolist())
print(df.head())
# Out:
# 🧾 Columns in CSV: ['shipment_id', 'timestamp', 'gps_lat', 'gps_long', 'rfid_tag', 'package_temp_c', 'humidity_percent', 'status']
#   shipment_id                   timestamp    gps_lat    gps_long  rfid_tag  \
# 0   SHP980988  2025-05-15 13:52:59.194834  11.721861  122.739816  RFID1098
# 1   SHP650973  2025-05-15 07:19:59.194993  13.051399  121.518155  RFID1063
# 2   SHP339067  2025-05-15 05:03:59.195050  13.867232  122.339907  RFID1010
# 3   SHP328994  2025-05-15 20:11:59.195101  14.814776  122.012883  RFID1096
# 4   SHP634775  2025-05-15 15:02:59.195151  10.127991  120.478309  RFID1037
#
#    package_temp_c  humidity_percent            status
# 0            6.80             43.68        In Transit
# 1            9.49             59.35    Arrived at Hub
# 2            6.63             34.58           Delayed
# 3            9.23             30.99           Delayed
# 4            8.04             46.65  Out for Delivery

# %%
# Step 2: Connect to Ganache
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))

if web3.is_connected():
    print("✅ Connected to Ganache!")
else:
    raise Exception("❌ Could not connect to Ganache. Please check RPC URL.")
# Out:
# ✅ Connected to Ganache!

# %%
# Step 3: Contract Setup
contract_address = Web3.to_checksum_address("0x36ea3165e2d6d0f52e361c302c74e429c9d54e80")

# Set the default account (convert if necessary)
web3.eth.default_account = Web3.to_checksum_address("0x3AF9Cb6ae4EA87Bc4178A74c7700f1868C807c20")



# Updated ABI for IoTDataStorage
abi = [
	{
		"inputs": [],
		"stateMutability": "nonpayable",
		"type": "constructor"
	},
	{
		"anonymous": False,
		"inputs": [
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "packageId",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "temperature",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "latitude",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "longitude",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "status",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "rfidTag",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "humidity",
				"type": "string"
			}
		],
		"name": "RowDataStored",
		"type": "event"
	},
	{
		"inputs": [],
		"name": "MAX_ENTRIES",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"name": "dataRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "packageId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "temperature",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "latitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "longitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "status",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "rfidTag",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "humidity",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "index",
				"type": "uint256"
			}
		],
		"name": "getData",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "packageId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "temperature",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "latitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "longitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "status",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "rfidTag",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "humidity",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "getDataCount",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "owner",
		"outputs": [
			{
				"internalType": "address",
				"name": "",
				"type": "address"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "packageId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "temperature",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "latitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "longitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "status",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "rfidTag",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "humidity",
				"type": "string"
			}
		],
		"name": "storeRowData",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	}
]
# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)

# Update function calls
def send_iot_data(package_id, category, value):
    txn = contract.functions.storeData(package_id, category, value).transact({
        'from': web3.eth.default_account,
        'gas': 300000
    })
    receipt = web3.eth.wait_for_transaction_receipt(txn)
    print(f"📦 {package_id} | {category}: {value} | ✅ Txn Hash: {receipt.transactionHash.hex()}")




# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)
print(f"✅ Connected to Smart Contract at {contract_address}")
# Out:
# ✅ Connected to Smart Contract at 0x36Ea3165e2D6D0F52E361c302C74e429c9D54E80

# %%
def send_row_data(package_id, temperature, latitude, longitude, status, rfid_tag, humidity):
    txn = contract.functions.storeRowData(
        package_id,
        temperature,
        latitude,
        longitude,
        status,
        rfid_tag,
        humidity
    ).transact({
        'from': web3.eth.default_account,
        'gas': 300000
    })
    receipt = web3.eth.wait_for_transaction_receipt(txn)
    print(f"📦 Row Data | PackageId: {package_id} | ✅ Txn Hash: {receipt.transactionHash.hex()}")

# Step 5: Loop through and send all data
for _, row in df.iterrows():
    if contract.functions.getDataCount().call() >= 100:
        print("⚠️ Storage limit reached. Stopping data upload.")
        break

    package_id = str(row["shipment_id"])
    temperature = f"{row['package_temp_c']}°C"
    latitude = str(row["gps_lat"])
    longitude = str(row["gps_long"])
    status = str(row["status"])
    rfid_tag = str(row["rfid_tag"])
    humidity = f"{row['humidity_percent']}%"

    send_row_data(package_id, temperature, latitude, longitude, status, rfid_tag, humidity)
    time.sleep(0.1)  # prevent flooding

# Step 6: Retrieve and display the first stored record
total_records = contract.functions.getDataCount().call()
print(f"📊 Total IoT records stored: {total_records}")

if total_records > 0:
    try:
        # Retrieve the first stored record from the smart contract
        record = contract.functions.getData(0).call()
        print(
            f"📄 First Record: "
            f"Timestamp={record[0]}, "
            f"PackageId={record[1]}, "
            f"Temperature={record[2]}, "
            f"Latitude={record[3]}, "
            f"Longitude={record[4]}, "
            f"Status={record[5]}, "
            f"RFID Tag={record[6]}, "
            f"Humidity={record[7]}"
        )
    except Exception as e:
        print(f"❌ Failed to retrieve the first record: {e}")
else:
    print("⚠️ No records found.")
# Out:
# 📦 Row Data | PackageId: SHP980988 | ✅ Txn Hash: f2aa524e0d2afa06af0d6f88ce75e4c3be8f7d12698942d366bc23d9edd06834
# 📦 Row Data | PackageId: SHP650973 | ✅ Txn Hash: 98cc5283480796bb6a545c50836ed79d86891c9860573fb392bc96d4320c886d
# 📦 Row Data | PackageId: SHP339067 | ✅ Txn Hash: 63b2406b1deb59f9eb341276605051339a3ba5a34be5a39312be467d849e3a96
# 📦 Row Data | PackageId: SHP328994 | ✅ Txn Hash: 98f9c78cfd2bcb86c65e321c9102962186584ffcb5e0650e889c6fabe16bebf1
# 📦 Row Data | PackageId: SHP634775 | ✅ Txn Hash: 558a72ac98a16e9b208e883166a962d97a9a68fbdf1ca83a57b8e91aa5270a9b
# 📦 Row Data | PackageId: SHP740472 | ✅ Txn Hash: 02607cc957afe1e68275ece6e03cca218b4f043214e32b28f6bb5709131557f7
# 📦 Row Data | PackageId: SHP600852 | ✅ Txn Hash: 7895d09673d8cf39e81f86aaf45c8db6b35b4c013b90bf39e334648287773074
# 📦 Row Data | PackageId: SHP826649 | ✅ Txn Hash: 2ac2e455c2a7c0f3929f6baf3bb372beff2a50ca714fb8cfda648d0ab711e8f4
# 📦 Row Data | PackageId: SHP658564 | ✅ Txn Hash: fda1c0b97c7e3c1cdaa4e3be158924eab0ed1dc00c6b32194b003c8220a84be8
# 📦 Row Data | PackageId: SHP691368 | ✅ Txn Hash: 3248c26f2ad6724164c4a2a6bcc0c6f9a7b6cac11536f023676e572e2893e5ad
# 📦 Row Data | PackageId: SHP215221 | ✅ Txn Hash: 6943645e4a75cc02a205f115cff86de526f4c2c848791cc22e2c8cba19cc1cdd
# 📦 Row Data | PackageId: SHP953174 | ✅ Txn Hash: 451516354d95e0cd1c9729a5324d647399e2ea91388ba4cc5c287ee2a3574643
# 📦 Row Data | PackageId: SHP568912 | ✅ Txn Hash: 1c61d69eb38d8ba5d41ddbc3e9eb59aa077dec6754b23c550306fb8eda3c34b4
# 📦 Row Data | PackageId: SHP426348 | ✅ Txn Hash: cfe8e5aa72e8655d58bd8f4a2a07447dac63fe71a785afb58e0623a303a619f2
# 📦 Row Data | PackageId: SHP580830 | ✅ Txn Hash: 3791ca76ad8d4858aed3dca6f0f1cf49c700ec6cb9d49a339cae6391d000b779
# 📦 Row Data | PackageId: SHP556625 | ✅ Txn Hash: dd23e12e0ad57f81a107d25f35f266e3a82c110985fe03aa9d08eef4ecf04ca6
# 📦 Row Data | PackageId: SHP318088 | ✅ Txn Hash: a5692ad41af4b6c90eea1ab49effb5d7a15c04ecd7434133cf96785dd8e8800b
# 📦 Row Data | PackageId: SHP634605 | ✅ Txn Hash: 87b12a6bdfa0e313702aad2c27d77f2b260abd3bddde144dc1c0f170a06ab8bb
# 📦 Row Data | PackageId: SHP998778 | ✅ Txn Hash: 295881c0089df7184bb9228115c8609289dcf0a9a257fcb8990692191e82a507
# 📦 Row Data | PackageId: SHP177707 | ✅ Txn Hash: c8f3bee50d827909fc31730d7dfa78e3206bdf77ea482d512e11f893444df41b
# 📦 Row Data | PackageId: SHP709628 | ✅ Txn Hash: 8679e2861fa256040f8dceb86ed7bdba0af45bbfcf81670749bbe1faab2ef58f
# 📦 Row Data | PackageId: SHP241936 | ✅ Txn Hash: 4787466fc86fd135ec46f62038ce89c3acfc55eda8db7b8621c121e9a3a877a1
# 📦 Row Data | PackageId: SHP330380 | ✅ Txn Hash: c8443cd5c4ae1a0d5dfbc0ff1d1d9051049269e01e006bc7e2546a2c1eb18ed0
# 📦 Row Data | PackageId: SHP796588 | ✅ Txn Hash: 8263dc3a22dd99f522ed4a5d70213e364b3713d95a64576e771c471233f15441
# 📦 Row Data | PackageId: SHP990568 | ✅ Txn Hash: 206ab761d6efafe178eecba403893022240a09345757569089035810e5270cde
# 📦 Row Data | PackageId: SHP264350 | ✅ Txn Hash: ab1c119c9e8b2425c6941752eda674e98f366e31be413355f8cb87dafb5ada98
# 📦 Row Data | PackageId: SHP773798 | ✅ Txn Hash: 4ff8ac7b102ef15c1265e4b72f7e43bf8284c7105da2b92814584c5bcfee439a
# 📦 Row Data | PackageId: SHP608728 | ✅ Txn Hash: a2fd6a029e7bd6b3a79ab7335bf4c32f5103451d9cff14d2a64fcaab14e79fdb
# 📦 Row Data | PackageId: SHP141010 | ✅ Txn Hash: ee852ddffdee3bf6e58eb7cd90a99896053a18b0dada743b86275a19a5706c4b
# 📦 Row Data | PackageId: SHP774464 | ✅ Txn Hash: 5b012cfe8654667e56f2895ec3c9a40eb34ed442085c7fdbe5de81a4b4657cf2
# 📦 Row Data | PackageId: SHP611919 | ✅ Txn Hash: 31d609383eb201490fe520544677844990b11a6abcfdbd90bbf78182b1a698a9
# 📦 Row Data | PackageId: SHP109816 | ✅ Txn Hash: d0cdedc400b4693e36c40d857caf3f77fc3579a568788ccc43d5378fa80339b7
# 📦 Row Data | PackageId: SHP229998 | ✅ Txn Hash: 5eea437a5448e7e7a6c76e0f550b90017662256ee2189c526f842ffe10a88ed7
# 📦 Row Data | PackageId: SHP366512 | ✅ Txn Hash: f80848b84fce6b5302c0bb13d47b8958eb486fff94bf3884c855cd091ab34274
# 📦 Row Data | PackageId: SHP607606 | ✅ Txn Hash: 9e615b7d2cbc80e66ef175e2c0f47890c2308c482c8adc3aa2fc4a531b926cd2
# 📦 Row Data | PackageId: SHP554983 | ✅ Txn Hash: 3b28470c92b036b6dfeba82067d4060ddad2fbf9a3c975839dfc550a652305cb
# 📦 Row Data | PackageId: SHP528048 | ✅ Txn Hash: fc74ca0ac65e913950f0b3213deb4b4f2253e2565b8a737f0d5338ea79488a0e
# 📦 Row Data | PackageId: SHP269829 | ✅ Txn Hash: c088917781c46dc342d7e6b19cc3cc8016a9f65e8d276176b606bfa802404508
# 📦 Row Data | PackageId: SHP329804 | ✅ Txn Hash: 6adc81c14eef0ccddad606c52998c1931f7012ab3a85382aa1f7cc0d8c2fcf1b
# 📦 Row Data | PackageId: SHP534914 | ✅ Txn Hash: b3243d2c391c957508b33d8d6afeef639a2f05dcdf8c7049d6ee077f6cf21128
# 📦 Row Data | PackageId: SHP490031 | ✅ Txn Hash: d17da700740257721fc76dd3cf741032c89456bbc3c557bf234e91a7b204f2fe
# 📦 Row Data | PackageId: SHP186780 | ✅ Txn Hash: 6599b3d29fe4cf9b44e4aa9fec73bfc3a1d6abbb380177045bc677c8db4d3455
# 📦 Row Data | PackageId: SHP863344 | ✅ Txn Hash: ad6429c6d64227c4163db76778c5cd0e2e66c88a4b66683105030c94b0544814
# 📦 Row Data | PackageId: SHP705107 | ✅ Txn Hash: 35c80fc3bb066129e54a9b08e033fe0c625699436354d120d9621634bd2baeaa
# 📦 Row Data | PackageId: SHP872145 | ✅ Txn Hash: 20b98742e514232c53bd4243b4fc6cda7b8dab932fe960a6de668f4c00c3d8d7
# 📦 Row Data | PackageId: SHP952511 | ✅ Txn Hash: 1b157ea8c1ab52707eb427675019fa6ba4f53a7590beb303771b27d2ce3ec5c8
# 📦 Row Data | PackageId: SHP557978 | ✅ Txn Hash: 9ee7a58c4d37420006f978947bf9309420cb1d7b4a4343f3a2576310681f859c
# 📦 Row Data | PackageId: SHP565542 | ✅ Txn Hash: 52c7bdbb8a5a4e2305a9c9bbe7c3d5c2e0d54d411da9e575c353943edab92f1b
# 📦 Row Data | PackageId: SHP749526 | ✅ Txn Hash: ae9f732f62e9ac82cff1765749adeb0be1a9d31d36680bfb1fb028372cc414f0
# 📦 Row Data | PackageId: SHP236398 | ✅ Txn Hash: bfd8581458941f53fdf3b1d851013bb5bc6901198d54c1c17e9cccc12d4cbdf4
# 📦 Row Data | PackageId: SHP843084 | ✅ Txn Hash: 31d690095748cf13dbde6d969562e24b0f732060314dc3d97b6abb43ced121b8
# 📦 Row Data | PackageId: SHP113417 | ✅ Txn Hash: 40c8f0061f300380b75252025afc29205aaa9c4d4b25925b66f3668a547f0ff1
# 📦 Row Data | PackageId: SHP968458 | ✅ Txn Hash: a72d4e2719b713fea8d1de3f2ec52f9ccb8477ccee871c4039b51d816e49133b
# 📦 Row Data | PackageId: SHP336999 | ✅ Txn Hash: ad3fc2844414d1cb8ed13efce70b0568398304686813f533123cd6d59d1d54a1
# 📦 Row Data | PackageId: SHP632885 | ✅ Txn Hash: 66d5ae8198da9c481f77670c29a9fbadcb6da144db768032320d12685f03c2e8
# 📦 Row Data | PackageId: SHP541955 | ✅ Txn Hash: 9616542dd958504f928841a98961e0d528930b19d12ade3cf6a551bf1ee3cfcb
# 📦 Row Data | PackageId: SHP622898 | ✅ Txn Hash: ed78dba51523d188ce3a6d01eae8f3ed515281f0d571f826e2a40b209a634cfa
# 📦 Row Data | PackageId: SHP256651 | ✅ Txn Hash: 42ac1d4070b4fe82ae08167c3c4d3fc595374af9d0b333e7edc392e25b60307a
# 📦 Row Data | PackageId: SHP793998 | ✅ Txn Hash: c97767e23304925e884c756aff683c2f4ff12b729fba77ca56b6769e9ec84117
# 📦 Row Data | PackageId: SHP739852 | ✅ Txn Hash: 76b7ec0ff2304451267f61dd9a90f786a005d7380b3f719799dbd50c29de1010
# 📦 Row Data | PackageId: SHP416497 | ✅ Txn Hash: a5a0943bf154231db364324d8b5332cb37ce076f60b45f6e3891ca043a5df41d
# 📦 Row Data | PackageId: SHP330418 | ✅ Txn Hash: 4bfcb3a5f7abc6e401b7b10ad292a8ebb730fa9d6c6ac6c596c659389ff6e841
# 📦 Row Data | PackageId: SHP556375 | ✅ Txn Hash: a96fabc6a0aaed80f75f4b86a95783a1571674ebc7976c62b267cc4fdf5da805
# 📦 Row Data | PackageId: SHP967473 | ✅ Txn Hash: 3ef6ce903e0f6c4a788032b53766295f6df28e36f3f660e654fbb03a80eef0a9
# 📦 Row Data | PackageId: SHP412723 | ✅ Txn Hash: 064293ff3ccca24ad1312b746e9b40523f2f7863d3637094fe6e1761f82f99ef
# 📦 Row Data | PackageId: SHP934221 | ✅ Txn Hash: 23f427396aff57c82fa851f2aff4653df4da838946983f323ff97b713e3cd4e6
# 📦 Row Data | PackageId: SHP409631 | ✅ Txn Hash: d93170fc2cadece19ce298c9420312fc212928b7676e8a744653d5db433569d1
# 📦 Row Data | PackageId: SHP238777 | ✅ Txn Hash: 3e13c65ffbec0417fcfde4e4e46457200ea9176576c6cc2f133b5c5ec57be0e8
# 📦 Row Data | PackageId: SHP846046 | ✅ Txn Hash: 2c1c06e1e1ec0a66df98be46dfd9a2c9d47484b9ba91c625abc043ddec3db71d
# 📦 Row Data | PackageId: SHP728554 | ✅ Txn Hash: 581f252978d85ca4db153248af3836da124667f0ebd8e1d7ce14d18b3b40e435
# 📦 Row Data | PackageId: SHP644220 | ✅ Txn Hash: 9c4caaff56dbc5a1278d342bd21d4ad88c9cd727bbda30ad77db4160d823ab4b
# 📦 Row Data | PackageId: SHP541286 | ✅ Txn Hash: 546a37fe9b1182e638c7830ca9f128bae7caf463e3a41d141ddee128a2ad2c04
# 📦 Row Data | PackageId: SHP521638 | ✅ Txn Hash: 96a6531a175b6ba99537b0db87589b908bd4e5525a2d5edae6e4ec5ee955b3ca
# 📦 Row Data | PackageId: SHP123313 | ✅ Txn Hash: f824e10b3d78a76c0fcbe8cc66954791c3f0487c446a1db91705f7e772b65053
# 📦 Row Data | PackageId: SHP883683 | ✅ Txn Hash: 2dfa1a7c0752f84d48381f3d39ee443ceaee10ab5d939f298161add3d18e6dd1
# 📦 Row Data | PackageId: SHP530950 | ✅ Txn Hash: 9876bc3ab35ae33805817777142a749db1a2325212ac458910ff92ab194ba7a3
# 📦 Row Data | PackageId: SHP430871 | ✅ Txn Hash: 781e50b99550e6db46dcc5cdba38e3bb3d5bf081fab66e68863ddcb6d2284fc8
# 📦 Row Data | PackageId: SHP892109 | ✅ Txn Hash: 20480e9b05880ea021579cb972806f5d865df0e3aa985fad9e8dcbbc321cfdce
# 📦 Row Data | PackageId: SHP390435 | ✅ Txn Hash: f27ec09f078cda0205f6e11d059291b0b88dcda7f1cef12a5d1d014e2bdc2b0c
# 📦 Row Data | PackageId: SHP623255 | ✅ Txn Hash: d35c51e80e21f2ecefd3354705875b22c2229c3059a4374f7986393687c53a3d
# 📦 Row Data | PackageId: SHP117659 | ✅ Txn Hash: 09af5f735e7f3e1fa3e2d8da13b7b5d5c58c24ada7b383220b3c6e0c54123b13
# 📦 Row Data | PackageId: SHP395029 | ✅ Txn Hash: 48249611898020b7e684f36f15f7711d2d55908a9229e5300d596c0cae89f53a
# 📦 Row Data | PackageId: SHP400605 | ✅ Txn Hash: cbb9c78e3fb9a2e6ae9d26afce45550bf56728dbfb716a73792037f58569275d
# 📦 Row Data | PackageId: SHP367826 | ✅ Txn Hash: 81d6f896f6898dbc4d491aa72130a06b5f0c91d53dcb2dc3ef42416ac19b7825
# 📦 Row Data | PackageId: SHP839101 | ✅ Txn Hash: 8852aa60a39b05ef69fe4fde8b533222d60d040bf26e14fd4de78dc683c5d7e2
# 📦 Row Data | PackageId: SHP185176 | ✅ Txn Hash: 1323330eb4df9e6112b278d2020efce342a387296d86b3302b81a9cd81c2b3c1
# 📦 Row Data | PackageId: SHP545079 | ✅ Txn Hash: a21ff5d049ed42b2edfc7a5357f5f97ae78cdeba74a41eda0780fe4ede289b7a
# 📦 Row Data | PackageId: SHP905681 | ✅ Txn Hash: d7bae43b9b70f1640d1324789f79d257ed638a045f0853b4634d8e0514cef46c
# 📦 Row Data | PackageId: SHP479380 | ✅ Txn Hash: 15a3976ebdb7a7ebf9f3b21f2baaeea9cad88063159a08a640e045f983f7f19e
# 📦 Row Data | PackageId: SHP368600 | ✅ Txn Hash: 46d475b66e26aa6629b27fa3e8cb49671a9c90b91a403f823d7f605fc3435756
# 📦 Row Data | PackageId: SHP511918 | ✅ Txn Hash: f99975e64fe16b95911db1bdc8f9346240a9127ae18869b7fe1bba0e52fb2e3a
# 📦 Row Data | PackageId: SHP835655 | ✅ Txn Hash: b8a05056a0a1a0349037da085a30564fb06b74e50500d1d3934e73c27e3d84fb
# 📦 Row Data | PackageId: SHP498416 | ✅ Txn Hash: ca3507153c3ee67f6821ffcd780ae137c4fbdf4ca6d19f85e6f2e8b4f523d966
# 📦 Row Data | PackageId: SHP332425 | ✅ Txn Hash: bd6637e64906d8b3e0f18cccfbe2138694cadea5173cb611fff723e14de12c3b
# 📦 Row Data | PackageId: SHP452490 | ✅ Txn Hash: 6bbf90f5def685422d43e8d8718ce3e9bc48cc29233a87c81801d24d3aba01d8
# 📦 Row Data | PackageId: SHP977623 | ✅ Txn Hash: 476776a5cc50017088af42af40be9a936466eb4c60c93cac789a027b1efd0fa8
# 📦 Row Data | PackageId: SHP395905 | ✅ Txn Hash: e8c6709833a6a585172d56d9f094a7fb2224d36f63d950f535f037fc31296316
# 📦 Row Data | PackageId: SHP578667 | ✅ Txn Hash: 9b89ebdcf4169b9e725b99934ddcf0295700ec537452295deabb46b7d5a9fe02
# 📦 Row Data | PackageId: SHP249701 | ✅ Txn Hash: 1530e76c0e0029cc09b52d50223ebe0a9b438c8f83cda885d09a492aceeb6aa2
# 📦 Row Data | PackageId: SHP560143 | ✅ Txn Hash: b90f04f7b09b073015570404c396814b671b66035b41da4ae71f8b7684886e8b
# 📊 Total IoT records stored: 100
# 📄 First Record: Timestamp=1749476676, PackageId=SHP980988, Temperature=6.8°C, Latitude=11.721861, Longitude=122.739816, Status=In Transit, RFID Tag=RFID1098, Humidity=43.68%
