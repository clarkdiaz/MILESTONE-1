# %%
import pandas as pd
from web3 import Web3
import time

# Step 1: Load CSV
df = pd.read_csv("resources/smart_logistics_data.csv")
print("🧾 Columns in CSV:", df.columns.tolist())
print(df.head())

# Step 2: Connect to Ganache
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))

if web3.is_connected():
    print("✅ Connected to Ganache!")
else:
    raise Exception("❌ Could not connect to Ganache. Please check RPC URL.")

# Step 3: Contract Setup
contract_address = Web3.to_checksum_address("0x81ec70617b9b31f4657f5c94785e8ca6c798d645")

# Set the default account (convert if necessary)
web3.eth.default_account = Web3.to_checksum_address("0x3AF9Cb6ae4EA87Bc4178A74c7700f1868C807c20")



# Updated ABI for IoTDataStorage
abi = [
	{
		"inputs": [],
		"stateMutability": "nonpayable",
		"type": "constructor"
	},
	{
		"anonymous": False,
		"inputs": [
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "packageId",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "temperature",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "latitude",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "longitude",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "status",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "rfidTag",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "humidity",
				"type": "string"
			}
		],
		"name": "RowDataStored",
		"type": "event"
	},
	{
		"inputs": [],
		"name": "MAX_ENTRIES",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"name": "dataRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "packageId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "temperature",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "latitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "longitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "status",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "rfidTag",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "humidity",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "index",
				"type": "uint256"
			}
		],
		"name": "getData",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "packageId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "temperature",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "latitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "longitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "status",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "rfidTag",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "humidity",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "getDataCount",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "owner",
		"outputs": [
			{
				"internalType": "address",
				"name": "",
				"type": "address"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "packageId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "temperature",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "latitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "longitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "status",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "rfidTag",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "humidity",
				"type": "string"
			}
		],
		"name": "storeRowData",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	}
]
# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)

# Update function calls
def send_iot_data(package_id, category, value):
    txn = contract.functions.storeData(package_id, category, value).transact({
        'from': web3.eth.default_account,
        'gas': 300000
    })
    receipt = web3.eth.wait_for_transaction_receipt(txn)
    print(f"📦 {package_id} | {category}: {value} | ✅ Txn Hash: {receipt.transactionHash.hex()}")

# Retrieve total records
total_records = contract.functions.getDataCount().call()
print(f"📊 Total IoT records stored: {total_records}")

if total_records > 0:
    first_record = contract.functions.getData(0).call()
    print("📄 First Stored Record:", first_record)
else:
    print("⚠️ No records found.")



# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)


# Set default sender (first account from Ganache)
web3.eth.default_account = web3.eth.accounts[0]

print(f"✅ Connected to Smart Contract at {contract_address}")


def send_row_data(package_id, temperature, latitude, longitude, status, rfid_tag, humidity):
    txn = contract.functions.storeRowData(
        package_id,
        temperature,
        latitude,
        longitude,
        status,
        rfid_tag,
        humidity
    ).transact({
        'from': web3.eth.default_account,
        'gas': 300000
    })
    receipt = web3.eth.wait_for_transaction_receipt(txn)
    print(f"📦 Row Data | PackageId: {package_id} | ✅ Txn Hash: {receipt.transactionHash.hex()}")

# Step 5: Loop through and send all data
for _, row in df.iterrows():
    if contract.functions.getDataCount().call() >= 100:
        print("⚠️ Storage limit reached. Stopping data upload.")
        break

    package_id = str(row["shipment_id"])
    temperature = f"{row['package_temp_c']}°C"
    latitude = str(row["gps_lat"])
    longitude = str(row["gps_long"])
    status = str(row["status"])
    rfid_tag = str(row["rfid_tag"])
    humidity = f"{row['humidity_percent']}%"

    send_row_data(package_id, temperature, latitude, longitude, status, rfid_tag, humidity)
    time.sleep(0.1)  # prevent flooding

# Step 6: Retrieve and display records
total_records = contract.functions.getDataCount().call()
print(f"📊 Total IoT records stored: {total_records}")

if total_records > 0:
    for i in range(total_records):
        try:
            # Retrieve the full row data from the smart contract
            record = contract.functions.getData(i).call()
            print(
                f"📄 Record {i}: "
                f"Timestamp={record[0]}, "
                f"PackageId={record[1]}, "
                f"Temperature={record[2]}, "
                f"Latitude={record[3]}, "
                f"Longitude={record[4]}, "
                f"Status={record[5]}"
            )
        except Exception as e:
            print(f"❌ Failed to retrieve record {i}: {e}")
else:
    print("⚠️ No records found.")
# Out:
# 🧾 Columns in CSV: ['shipment_id', 'timestamp', 'gps_lat', 'gps_long', 'rfid_tag', 'package_temp_c', 'humidity_percent', 'status']
#   shipment_id                   timestamp    gps_lat    gps_long  rfid_tag  \
# 0   SHP980988  2025-05-15 13:52:59.194834  11.721861  122.739816  RFID1098
# 1   SHP650973  2025-05-15 07:19:59.194993  13.051399  121.518155  RFID1063
# 2   SHP339067  2025-05-15 05:03:59.195050  13.867232  122.339907  RFID1010
# 3   SHP328994  2025-05-15 20:11:59.195101  14.814776  122.012883  RFID1096
# 4   SHP634775  2025-05-15 15:02:59.195151  10.127991  120.478309  RFID1037
#
#   package_temp_c  humidity_percent            status
# 0           6.8C             43.68        In Transit
# 1          9.49C             59.35    Arrived at Hub
# 2          6.63C             34.58           Delayed
# 3          9.23C             30.99           Delayed
# 4          8.04C             46.65  Out for Delivery
# ✅ Connected to Ganache!
# 📊 Total IoT records stored: 0
# ⚠️ No records found.
# ✅ Connected to Smart Contract at 0x81ec70617b9B31f4657F5C94785e8cA6c798D645
# 📦 Row Data | PackageId: SHP980988 | ✅ Txn Hash: 4503d1312217f111ed9a2b63d3101aaf14542761d608a10c4543bbd2578b21b8
# 📦 Row Data | PackageId: SHP650973 | ✅ Txn Hash: 498eca3d3a02ed43f30c824741c6ebd25add14375b3eace57f015d0f1bc3e854
# 📦 Row Data | PackageId: SHP339067 | ✅ Txn Hash: a1b5a5434f2fc58ba7d69b7ce51fb1cbdc6f259535c9c0bf05109a4281191c4e
# 📦 Row Data | PackageId: SHP328994 | ✅ Txn Hash: 9ca813079d94e69d090d0737d70a7861af36237803c6d1449e5750635f773b65
# 📦 Row Data | PackageId: SHP634775 | ✅ Txn Hash: 0f42e65a7c8370a8a46e5c4b6be8e92a8963abc0217370b94350c39875ff4746
# 📦 Row Data | PackageId: SHP740472 | ✅ Txn Hash: c2c4a2998a8fde8319f1f818f339bbf21c296a9277c37ba08e5845da969d1fce
# 📦 Row Data | PackageId: SHP600852 | ✅ Txn Hash: c18b9795c28b1414bf9e29c960ca70ee569a9f1fcd83b28197a5d4fe2ec98350
# 📦 Row Data | PackageId: SHP826649 | ✅ Txn Hash: 27b6a628b3da3e4947e4d6ff5ab9a38b840e66e52f257a6aa11ed2b4a385fc7c
# 📦 Row Data | PackageId: SHP658564 | ✅ Txn Hash: 8fbdb3c172905af882b93e443e79c3d1cee319f31237e4700382c2ac1306f13d
# 📦 Row Data | PackageId: SHP691368 | ✅ Txn Hash: 2747358a7bdd58d5215eb76fc803764d9a48e05614ceff9d2690e12c354022a5
# 📦 Row Data | PackageId: SHP215221 | ✅ Txn Hash: 5feca0e314c1b22fa4c851f8632d1b3756c7896c17e1dce92062daa7be1ffa34
# 📦 Row Data | PackageId: SHP953174 | ✅ Txn Hash: ff86268836ad81d81211ee158d271e29d63353ddf9b9683fa89f954917596a34
# 📦 Row Data | PackageId: SHP568912 | ✅ Txn Hash: bf52709cd19f706ff3e51c9dbd04ce5a60292494a2c284be2d7ea6b2cdf2ef18
# 📦 Row Data | PackageId: SHP426348 | ✅ Txn Hash: 2ff29132a7cefa5285ed4f9a622b90707b0ac2ddfdbc5780e9b257135d88587f
# 📦 Row Data | PackageId: SHP580830 | ✅ Txn Hash: 5d2667ec55855e5e308272fb877dce9af1f39c43edd89774bdf8e056fb39eb87
# 📦 Row Data | PackageId: SHP556625 | ✅ Txn Hash: 7fa1bb31b8af5047775b2dc7dcb96e139cb8d3f623f52fc81400f15cd9501f8a
# 📦 Row Data | PackageId: SHP318088 | ✅ Txn Hash: d8a9c89717560fc915fb3a0b1c4eef561abbe72bdaa087f046d8b52385b2dde7
# 📦 Row Data | PackageId: SHP634605 | ✅ Txn Hash: 12063736104cceafacd5999d0b4842c6a3642b95db201a3b65766404880575b3
# 📦 Row Data | PackageId: SHP998778 | ✅ Txn Hash: d1db23ea1562a6397696baa4a6430a48be1c67018a96427db23054fab026e34c
# 📦 Row Data | PackageId: SHP400605 | ✅ Txn Hash: 4bb5c7575bff093304d96d6932dd7a184411cc07f1668c1258fb752c9386027d
# 📦 Row Data | PackageId: SHP367826 | ✅ Txn Hash: 1d054954c48566a7360b7dbc58dd9de141b15bb5255fa7a4ed908f70b4563e85
# 📦 Row Data | PackageId: SHP839101 | ✅ Txn Hash: b82c5132751f76b98120f66b1bc6f34927ebf69ef4dbb34fd1670c4c37be96de
# 📦 Row Data | PackageId: SHP185176 | ✅ Txn Hash: e63f190e1b7185d88f6dec554ecd74846548a68bca0ac890e118a02a551b090b
# 📦 Row Data | PackageId: SHP545079 | ✅ Txn Hash: 089257638b65d371750ceed69639b1b492d6d54736eb89624a9173d4b3e281a8
# 📦 Row Data | PackageId: SHP905681 | ✅ Txn Hash: ebd74adf914649cbf6cbd806d7cc2cce30750f33863b0575883ee8901e6661ab
# 📦 Row Data | PackageId: SHP479380 | ✅ Txn Hash: a7a0e74038be41b7ee9875cb060d3d20d9a91f1cf970789771ebad15fab740c6
# 📦 Row Data | PackageId: SHP368600 | ✅ Txn Hash: d51f0148ff33a489c95a3f049a8d5f160d6e1bcc9f561b05ec9ccee46e97a6f9
# 📦 Row Data | PackageId: SHP511918 | ✅ Txn Hash: 30180e8097fa2dfbc92f0c7268cc81c0968129e0d9fc5da24b99fe2599dbbf9a
# 📦 Row Data | PackageId: SHP835655 | ✅ Txn Hash: cc66e906bd8d5b8581df38e2489bb6fb57d70f30aa6a6eea1746247e218f0289
# 📦 Row Data | PackageId: SHP498416 | ✅ Txn Hash: 8bba0e09d929cdb7135a6bdaaf214a88ac85579abbaee01dc79d423caaa6f3b7
# 📦 Row Data | PackageId: SHP332425 | ✅ Txn Hash: dc758ff8f0d90e1bb0dc299016d6c2a666c2fa99f12c08ff22cb78fd5eb14f01
# 📦 Row Data | PackageId: SHP452490 | ✅ Txn Hash: 11050b4e96160edd508dd341ca6d114df947947a7ab50f91ccff2efd2783f358
# 📦 Row Data | PackageId: SHP977623 | ✅ Txn Hash: c1919eece8e2aac3765cbc4229c5c185e6116435633235dfb993b65ddb57a9e8
# 📦 Row Data | PackageId: SHP395905 | ✅ Txn Hash: 4a8e249d072154e17ea630afc93c1dec1b4d73608dce5c6483ff6888beccd998
# 📦 Row Data | PackageId: SHP578667 | ✅ Txn Hash: efeb6d6a3cd503a9d7fe7e6eace4731f27bb9366d57f61dc88de62b47ae56f0c
# 📦 Row Data | PackageId: SHP249701 | ✅ Txn Hash: 5e3db25e6782006629174a35e3527fef449a26a7ccb5bbf7051c4e2e98298cc2
# 📦 Row Data | PackageId: SHP560143 | ✅ Txn Hash: 97c8aa273e3a9527fd0440af81a9ff64dde1d09711a4ba2c600ca09bb8048be8
# 📊 Total IoT records stored: 100
# 📄 Record 0: Timestamp=1749475918, PackageId=SHP980988, Temperature=6.8C°C, Latitude=11.721861, Longitude=122.739816, Status=In Transit
# 📄 Record 1: Timestamp=1749475918, PackageId=SHP650973, Temperature=9.49C°C, Latitude=13.051399, Longitude=121.518155, Status=Arrived at Hub
# 📄 Record 2: Timestamp=1749475918, PackageId=SHP339067, Temperature=6.63C°C, Latitude=13.867232, Longitude=122.339907, Status=Delayed
# 📄 Record 3: Timestamp=1749475918, PackageId=SHP328994, Temperature=9.23C°C, Latitude=14.814776, Longitude=122.012883, Status=Delayed
# 📄 Record 4: Timestamp=1749475918, PackageId=SHP634775, Temperature=8.04C°C, Latitude=10.127991, Longitude=120.478309, Status=Out for Delivery
# 📄 Record 5: Timestamp=1749475918, PackageId=SHP740472, Temperature=5.89°C, Latitude=12.276575, Longitude=123.106262, Status=Delayed
# 📄 Record 6: Timestamp=1749475919, PackageId=SHP600852, Temperature=6.94°C, Latitude=12.153, Longitude=124.309853, Status=Out for Delivery
# 📄 Record 7: Timestamp=1749475919, PackageId=SHP826649, Temperature=2.59°C, Latitude=10.473782, Longitude=124.980783, Status=Arrived at Hub
# 📄 Record 8: Timestamp=1749475919, PackageId=SHP658564, Temperature=3.49°C, Latitude=10.168827, Longitude=121.789855, Status=Delayed
# 📄 Record 9: Timestamp=1749475919, PackageId=SHP691368, Temperature=3.43°C, Latitude=10.857887, Longitude=124.927195, Status=Delayed
# 📄 Record 10: Timestamp=1749475919, PackageId=SHP215221, Temperature=4.12°C, Latitude=14.050442, Longitude=123.977595, Status=Arrived at Hub
# 📄 Record 11: Timestamp=1749475919, PackageId=SHP953174, Temperature=3.8°C, Latitude=14.771929, Longitude=123.354979, Status=Delayed
# 📄 Record 12: Timestamp=1749475919, PackageId=SHP568912, Temperature=3.61°C, Latitude=13.666493, Longitude=124.3028, Status=Delivered
# 📄 Record 13: Timestamp=1749475920, PackageId=SHP426348, Temperature=7.19°C, Latitude=10.263552, Longitude=121.428997, Status=Delayed
# 📄 Record 14: Timestamp=1749475920, PackageId=SHP580830, Temperature=6.84°C, Latitude=11.172752, Longitude=120.67059, Status=Out for Delivery
# 📄 Record 15: Timestamp=1749475920, PackageId=SHP556625, Temperature=4.38°C, Latitude=14.979811, Longitude=120.590276, Status=Arrived at Hub
# 📄 Record 16: Timestamp=1749475920, PackageId=SHP318088, Temperature=7.9°C, Latitude=13.809771, Longitude=120.597086, Status=Arrived at Hub
# 📄 Record 17: Timestamp=1749475920, PackageId=SHP634605, Temperature=2.6°C, Latitude=10.532615, Longitude=121.566852, Status=Out for Delivery
# 📄 Record 18: Timestamp=1749475920, PackageId=SHP998778, Temperature=5.31°C, Latitude=14.509577, Longitude=121.822857, Status=Delivered
# 📄 Record 19: Timestamp=1749475920, PackageId=SHP177707, Temperature=4.34°C, Latitude=14.32177, Longitude=124.566207, Status=Arrived at Hub
# 📄 Record 20: Timestamp=1749475920, PackageId=SHP709628, Temperature=5.34°C, Latitude=12.316259, Longitude=121.956474, Status=In Transit
# 📄 Record 21: Timestamp=1749475921, PackageId=SHP241936, Temperature=7.2°C, Latitude=13.203984, Longitude=122.701706, Status=Delivered
# 📄 Record 22: Timestamp=1749475921, PackageId=SHP330380, Temperature=7.38°C, Latitude=11.6041, Longitude=124.897328, Status=Delivered
# 📄 Record 23: Timestamp=1749475921, PackageId=SHP796588, Temperature=7.58°C, Latitude=11.650744, Longitude=122.397, Status=In Transit
# 📄 Record 24: Timestamp=1749475921, PackageId=SHP990568, Temperature=3.82°C, Latitude=13.332419, Longitude=122.844485, Status=Out for Delivery
# 📄 Record 25: Timestamp=1749475921, PackageId=SHP264350, Temperature=3.3°C, Latitude=12.417054, Longitude=124.614054, Status=In Transit
# 📄 Record 26: Timestamp=1749475921, PackageId=SHP773798, Temperature=6.55°C, Latitude=10.2095, Longitude=120.703298, Status=Out for Delivery
# 📄 Record 27: Timestamp=1749475921, PackageId=SHP608728, Temperature=9.29°C, Latitude=13.274999, Longitude=124.901386, Status=Arrived at Hub
# 📄 Record 28: Timestamp=1749475922, PackageId=SHP141010, Temperature=6.38°C, Latitude=12.986681, Longitude=121.007524, Status=Arrived at Hub
# 📄 Record 29: Timestamp=1749475922, PackageId=SHP774464, Temperature=5.62°C, Latitude=13.603956, Longitude=120.560158, Status=In Transit
# 📄 Record 30: Timestamp=1749475922, PackageId=SHP611919, Temperature=2.31°C, Latitude=10.036909, Longitude=120.716731, Status=Delayed
# 📄 Record 31: Timestamp=1749475922, PackageId=SHP109816, Temperature=6.83°C, Latitude=11.810313, Longitude=122.188404, Status=Delayed
# 📄 Record 32: Timestamp=1749475922, PackageId=SHP229998, Temperature=3.91°C, Latitude=10.935232, Longitude=124.650323, Status=Delivered
# 📄 Record 33: Timestamp=1749475922, PackageId=SHP366512, Temperature=8.08°C, Latitude=11.375589, Longitude=123.74278, Status=Delivered
# 📄 Record 34: Timestamp=1749475922, PackageId=SHP607606, Temperature=5.01°C, Latitude=12.872778, Longitude=122.720015, Status=Out for Delivery
# 📄 Record 35: Timestamp=1749475922, PackageId=SHP554983, Temperature=8.88°C, Latitude=14.463139, Longitude=124.788869, Status=Out for Delivery
# 📄 Record 36: Timestamp=1749475923, PackageId=SHP528048, Temperature=5.81°C, Latitude=14.598898, Longitude=122.383835, Status=Delayed
# 📄 Record 37: Timestamp=1749475923, PackageId=SHP269829, Temperature=5.31°C, Latitude=10.764124, Longitude=124.932578, Status=In Transit
# 📄 Record 38: Timestamp=1749475923, PackageId=SHP329804, Temperature=5.21°C, Latitude=14.632839, Longitude=121.071784, Status=In Transit
# 📄 Record 39: Timestamp=1749475923, PackageId=SHP534914, Temperature=9.72°C, Latitude=13.227058, Longitude=120.582968, Status=In Transit
# 📄 Record 40: Timestamp=1749475923, PackageId=SHP490031, Temperature=3.65°C, Latitude=14.348405, Longitude=120.075208, Status=Arrived at Hub
# 📄 Record 41: Timestamp=1749475923, PackageId=SHP186780, Temperature=7.76°C, Latitude=11.043719, Longitude=121.195959, Status=Out for Delivery
# 📄 Record 42: Timestamp=1749475923, PackageId=SHP863344, Temperature=4.29°C, Latitude=11.510643, Longitude=121.408825, Status=Out for Delivery
# 📄 Record 43: Timestamp=1749475924, PackageId=SHP705107, Temperature=3.67°C, Latitude=14.727114, Longitude=123.411051, Status=Delayed
# 📄 Record 44: Timestamp=1749475924, PackageId=SHP872145, Temperature=5.79°C, Latitude=13.492835, Longitude=121.036003, Status=Arrived at Hub
# 📄 Record 45: Timestamp=1749475924, PackageId=SHP952511, Temperature=5.33°C, Latitude=13.308691, Longitude=124.433728, Status=In Transit
# 📄 Record 46: Timestamp=1749475924, PackageId=SHP557978, Temperature=4.63°C, Latitude=14.270428, Longitude=122.007746, Status=Arrived at Hub
# 📄 Record 47: Timestamp=1749475924, PackageId=SHP565542, Temperature=7.3°C, Latitude=12.628608, Longitude=121.835915, Status=Delayed
# 📄 Record 48: Timestamp=1749475924, PackageId=SHP749526, Temperature=5.2°C, Latitude=12.717485, Longitude=124.849842, Status=In Transit
# 📄 Record 49: Timestamp=1749475924, PackageId=SHP236398, Temperature=7.26°C, Latitude=13.90291, Longitude=124.17452, Status=In Transit
# 📄 Record 50: Timestamp=1749475924, PackageId=SHP843084, Temperature=6.86°C, Latitude=11.42335, Longitude=124.030811, Status=Out for Delivery
# 📄 Record 51: Timestamp=1749475925, PackageId=SHP113417, Temperature=2.41°C, Latitude=14.563886, Longitude=124.26679, Status=In Transit
# 📄 Record 52: Timestamp=1749475925, PackageId=SHP968458, Temperature=8.28°C, Latitude=11.20207, Longitude=124.271668, Status=Delayed
# 📄 Record 53: Timestamp=1749475925, PackageId=SHP336999, Temperature=8.34°C, Latitude=13.256188, Longitude=122.350688, Status=Delayed
# 📄 Record 54: Timestamp=1749475925, PackageId=SHP632885, Temperature=8.74°C, Latitude=11.167574, Longitude=122.05739, Status=Delayed
# 📄 Record 55: Timestamp=1749475925, PackageId=SHP541955, Temperature=2.04°C, Latitude=14.039782, Longitude=121.754377, Status=Arrived at Hub
# 📄 Record 56: Timestamp=1749475925, PackageId=SHP622898, Temperature=9.05°C, Latitude=12.286937, Longitude=124.732357, Status=Out for Delivery
# 📄 Record 57: Timestamp=1749475925, PackageId=SHP256651, Temperature=4.54°C, Latitude=13.762839, Longitude=123.707489, Status=Out for Delivery
# 📄 Record 58: Timestamp=1749475926, PackageId=SHP793998, Temperature=7.02°C, Latitude=11.025627, Longitude=122.211304, Status=Delivered
# 📄 Record 59: Timestamp=1749475926, PackageId=SHP739852, Temperature=5.08°C, Latitude=11.036341, Longitude=123.181455, Status=Delayed
# 📄 Record 60: Timestamp=1749475926, PackageId=SHP416497, Temperature=3.85°C, Latitude=10.444118, Longitude=122.163626, Status=Out for Delivery
# 📄 Record 61: Timestamp=1749475926, PackageId=SHP330418, Temperature=7.76°C, Latitude=12.015889, Longitude=123.558466, Status=In Transit
# 📄 Record 62: Timestamp=1749475926, PackageId=SHP556375, Temperature=8.06°C, Latitude=10.225456, Longitude=124.924612, Status=Delivered
# 📄 Record 63: Timestamp=1749475926, PackageId=SHP967473, Temperature=9.54°C, Latitude=14.997228, Longitude=121.05551, Status=Delayed
# 📄 Record 64: Timestamp=1749475926, PackageId=SHP412723, Temperature=8.0°C, Latitude=14.717626, Longitude=120.930401, Status=Delayed
# 📄 Record 65: Timestamp=1749475926, PackageId=SHP934221, Temperature=2.13°C, Latitude=14.719466, Longitude=121.634125, Status=Out for Delivery
# 📄 Record 66: Timestamp=1749475927, PackageId=SHP409631, Temperature=8.54°C, Latitude=12.967918, Longitude=120.822638, Status=Arrived at Hub
# 📄 Record 67: Timestamp=1749475927, PackageId=SHP238777, Temperature=8.97°C, Latitude=14.85333, Longitude=120.581523, Status=Out for Delivery
# 📄 Record 68: Timestamp=1749475927, PackageId=SHP846046, Temperature=2.76°C, Latitude=11.198052, Longitude=120.348408, Status=Arrived at Hub
# 📄 Record 69: Timestamp=1749475927, PackageId=SHP728554, Temperature=9.79°C, Latitude=11.254858, Longitude=121.796016, Status=Arrived at Hub
# 📄 Record 70: Timestamp=1749475927, PackageId=SHP644220, Temperature=6.67°C, Latitude=14.87401, Longitude=122.559049, Status=Out for Delivery
# 📄 Record 71: Timestamp=1749475927, PackageId=SHP541286, Temperature=6.42°C, Latitude=12.559319, Longitude=123.033607, Status=In Transit
# 📄 Record 72: Timestamp=1749475927, PackageId=SHP521638, Temperature=8.32°C, Latitude=10.917232, Longitude=120.295846, Status=Out for Delivery
# 📄 Record 73: Timestamp=1749475928, PackageId=SHP123313, Temperature=5.35°C, Latitude=14.278345, Longitude=123.251457, Status=Out for Delivery
# 📄 Record 74: Timestamp=1749475928, PackageId=SHP883683, Temperature=8.7°C, Latitude=10.503114, Longitude=121.330726, Status=Delivered
# 📄 Record 75: Timestamp=1749475928, PackageId=SHP530950, Temperature=2.04°C, Latitude=12.499087, Longitude=120.806908, Status=In Transit
# 📄 Record 76: Timestamp=1749475928, PackageId=SHP430871, Temperature=3.17°C, Latitude=10.019221, Longitude=121.403563, Status=Delivered
# 📄 Record 77: Timestamp=1749475928, PackageId=SHP892109, Temperature=2.9°C, Latitude=12.974818, Longitude=123.68988, Status=Arrived at Hub
# 📄 Record 78: Timestamp=1749475928, PackageId=SHP390435, Temperature=6.94°C, Latitude=11.800719, Longitude=121.881357, Status=Delivered
# 📄 Record 79: Timestamp=1749475928, PackageId=SHP623255, Temperature=2.46°C, Latitude=11.556417, Longitude=122.901536, Status=In Transit
# 📄 Record 80: Timestamp=1749475928, PackageId=SHP117659, Temperature=4.69°C, Latitude=10.616837, Longitude=124.481355, Status=Arrived at Hub
# 📄 Record 81: Timestamp=1749475929, PackageId=SHP395029, Temperature=3.73°C, Latitude=11.700245, Longitude=124.426143, Status=Arrived at Hub
# 📄 Record 82: Timestamp=1749475929, PackageId=SHP400605, Temperature=8.85°C, Latitude=10.67408, Longitude=121.574709, Status=In Transit
# 📄 Record 83: Timestamp=1749475929, PackageId=SHP367826, Temperature=7.2°C, Latitude=10.200923, Longitude=123.758401, Status=Out for Delivery
# 📄 Record 84: Timestamp=1749475929, PackageId=SHP839101, Temperature=6.07°C, Latitude=12.457308, Longitude=120.774573, Status=Delayed
# 📄 Record 85: Timestamp=1749475929, PackageId=SHP185176, Temperature=5.9°C, Latitude=12.164928, Longitude=122.796686, Status=Arrived at Hub
# 📄 Record 86: Timestamp=1749475929, PackageId=SHP545079, Temperature=7.64°C, Latitude=11.327844, Longitude=123.779497, Status=Arrived at Hub
# 📄 Record 87: Timestamp=1749475929, PackageId=SHP905681, Temperature=3.12°C, Latitude=12.088353, Longitude=123.578549, Status=Delayed
# 📄 Record 88: Timestamp=1749475930, PackageId=SHP479380, Temperature=8.98°C, Latitude=10.416826, Longitude=121.691158, Status=In Transit
# 📄 Record 89: Timestamp=1749475930, PackageId=SHP368600, Temperature=6.35°C, Latitude=13.00452, Longitude=124.713652, Status=Arrived at Hub
# 📄 Record 90: Timestamp=1749475930, PackageId=SHP511918, Temperature=6.07°C, Latitude=10.047465, Longitude=121.75619, Status=Delayed
# 📄 Record 91: Timestamp=1749475930, PackageId=SHP835655, Temperature=3.72°C, Latitude=12.725454, Longitude=124.07048, Status=Arrived at Hub
# 📄 Record 92: Timestamp=1749475930, PackageId=SHP498416, Temperature=9.41°C, Latitude=12.358341, Longitude=121.599181, Status=Delivered
# 📄 Record 93: Timestamp=1749475930, PackageId=SHP332425, Temperature=5.12°C, Latitude=12.316754, Longitude=122.298518, Status=Delayed
# 📄 Record 94: Timestamp=1749475930, PackageId=SHP452490, Temperature=3.15°C, Latitude=11.735213, Longitude=120.798945, Status=Arrived at Hub
# 📄 Record 95: Timestamp=1749475930, PackageId=SHP977623, Temperature=5.46°C, Latitude=12.604902, Longitude=123.415914, Status=Arrived at Hub
# 📄 Record 96: Timestamp=1749475931, PackageId=SHP395905, Temperature=3.67°C, Latitude=14.433488, Longitude=122.436792, Status=Arrived at Hub
# 📄 Record 97: Timestamp=1749475931, PackageId=SHP578667, Temperature=2.34°C, Latitude=14.037778, Longitude=121.908669, Status=Arrived at Hub
# 📄 Record 98: Timestamp=1749475931, PackageId=SHP249701, Temperature=7.09°C, Latitude=13.679253, Longitude=123.121382, Status=Arrived at Hub
# 📄 Record 99: Timestamp=1749475931, PackageId=SHP560143, Temperature=8.53°C, Latitude=10.157576, Longitude=122.681713, Status=In Transit

# %%
total_records = contract.functions.getDataCount().call()
print(f"📊 Total IoT records stored: {total_records}")
# Out:
# 📊 Total IoT records stored: 100

# %%
import pandas as pd
import numpy as np

# Create a DataFrame from the retrieved records
data = []
total_records = contract.functions.getDataCount().call()

for i in range(total_records):
    try:
        # Retrieve the full row data from the smart contract
        record = contract.functions.getData(i).call()
        data.append({
            "timestamp": record[0],
            "package_id": record[1],
            "temperature": record[2],
            "latitude": record[3],
            "longitude": record[4],
            "status": record[5],
            "rfid_tag": record[6],
            "humidity": record[7],
        })
    except Exception as e:
        print(f"❌ Failed to retrieve record {i}: {e}")

# Convert the data into a DataFrame
df = pd.DataFrame(data)

# Handle missing values
df.fillna("", inplace=True)

import re

def extract_numeric(value):
    """Extracts the first floating point number from a string, or returns NaN if not found."""
    if pd.isnull(value):
        return np.nan
    match = re.search(r"[-+]?\d*\.\d+|\d+", str(value))
    return float(match.group()) if match else np.nan

# Preprocess numerical values
df["temperature"] = df["temperature"].apply(extract_numeric)
df["humidity"] = df["humidity"].apply(extract_numeric)
df["latitude"] = pd.to_numeric(df["latitude"], errors="coerce")
df["longitude"] = pd.to_numeric(df["longitude"], errors="coerce")

# Handle missing numerical values
df["temperature"] = df["temperature"].fillna(df["temperature"].mean())
df["humidity"] = df["humidity"].fillna(df["humidity"].mean())
df["latitude"] = df["latitude"].fillna(0)
df["longitude"] = df["longitude"].fillna(0) 

# Save the cleaned data to a CSV file
df.to_csv("cleaned_iot_data.csv", index=False)
print("✅ Cleaned IoT data saved successfully as cleaned_iot_data.csv")
# Out:
# ✅ Cleaned IoT data saved successfully as cleaned_iot_data.csv
