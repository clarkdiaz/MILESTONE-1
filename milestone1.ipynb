# %%
import pandas as pd
from web3 import Web3
import time

# Step 1: Load CSV
df = pd.read_csv("resources/smart_logistics_data.csv")
print("🧾 Columns in CSV:", df.columns.tolist())
print(df.head())
# Out:
# 🧾 Columns in CSV: ['shipment_id', 'timestamp', 'gps_lat', 'gps_long', 'rfid_tag', 'package_temp_c', 'humidity_percent', 'status']
#   shipment_id                   timestamp    gps_lat    gps_long  rfid_tag  \
# 0   SHP980988  2025-05-15 13:52:59.194834  11.721861  122.739816  RFID1098
# 1   SHP650973  2025-05-15 07:19:59.194993  13.051399  121.518155  RFID1063
# 2   SHP339067  2025-05-15 05:03:59.195050  13.867232  122.339907  RFID1010
# 3   SHP328994  2025-05-15 20:11:59.195101  14.814776  122.012883  RFID1096
# 4   SHP634775  2025-05-15 15:02:59.195151  10.127991  120.478309  RFID1037
#
#    package_temp_c  humidity_percent            status
# 0            6.80             43.68        In Transit
# 1            9.49             59.35    Arrived at Hub
# 2            6.63             34.58           Delayed
# 3            9.23             30.99           Delayed
# 4            8.04             46.65  Out for Delivery

# %%
# Step 2: Connect to Ganache
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))

if web3.is_connected():
    print("✅ Connected to Ganache!")
else:
    raise Exception("❌ Could not connect to Ganache. Please check RPC URL.")
# Out:
# ✅ Connected to Ganache!

# %%
# Step 3: Contract Setup
contract_address = Web3.to_checksum_address("0xf5234470b686639894f298d58776a31269d8cfcb")

# Set the default account (convert if necessary)
web3.eth.default_account = Web3.to_checksum_address("0x3AF9Cb6ae4EA87Bc4178A74c7700f1868C807c20")



# Updated ABI for IoTDataStorage
abi = [
	{
		"inputs": [],
		"stateMutability": "nonpayable",
		"type": "constructor"
	},
	{
		"anonymous": False,
		"inputs": [
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "packageId",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "temperature",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "latitude",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "longitude",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "status",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "rfidTag",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "humidity",
				"type": "string"
			}
		],
		"name": "RowDataStored",
		"type": "event"
	},
	{
		"inputs": [],
		"name": "MAX_ENTRIES",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"name": "dataRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "packageId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "temperature",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "latitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "longitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "status",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "rfidTag",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "humidity",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "index",
				"type": "uint256"
			}
		],
		"name": "getData",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "packageId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "temperature",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "latitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "longitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "status",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "rfidTag",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "humidity",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "getDataCount",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "owner",
		"outputs": [
			{
				"internalType": "address",
				"name": "",
				"type": "address"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "packageId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "temperature",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "latitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "longitude",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "status",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "rfidTag",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "humidity",
				"type": "string"
			}
		],
		"name": "storeRowData",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	}
]
# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)

# Update function calls
def send_iot_data(package_id, category, value):
    txn = contract.functions.storeData(package_id, category, value).transact({
        'from': web3.eth.default_account,
        'gas': 300000
    })
    receipt = web3.eth.wait_for_transaction_receipt(txn)
    print(f"📦 {package_id} | {category}: {value} | ✅ Txn Hash: {receipt.transactionHash.hex()}")




# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)
print(f"✅ Connected to Smart Contract at {contract_address}")
# Out:
# ✅ Connected to Smart Contract at 0xf5234470b686639894F298d58776A31269d8CFcb

# %%
def send_row_data(package_id, temperature, latitude, longitude, status, rfid_tag, humidity):
    txn = contract.functions.storeRowData(
        package_id,
        temperature,
        latitude,
        longitude,
        status,
        rfid_tag,
        humidity
    ).transact({
        'from': web3.eth.default_account,
        'gas': 300000
    })
    receipt = web3.eth.wait_for_transaction_receipt(txn)
    print(f"📦 Row Data | PackageId: {package_id} | ✅ Txn Hash: {receipt.transactionHash.hex()}")

# Step 5: Loop through and send all data
for _, row in df.iterrows():
    if contract.functions.getDataCount().call() >= 100:
        print("⚠️ Storage limit reached. Stopping data upload.")
        break

    package_id = str(row["shipment_id"])
    temperature = f"{row['package_temp_c']}°C"
    latitude = str(row["gps_lat"])
    longitude = str(row["gps_long"])
    status = str(row["status"])
    rfid_tag = str(row["rfid_tag"])
    humidity = f"{row['humidity_percent']}%"

    send_row_data(package_id, temperature, latitude, longitude, status, rfid_tag, humidity)
    time.sleep(0.1)  # prevent flooding

# Step 6: Retrieve and display the first stored record
total_records = contract.functions.getDataCount().call()
print(f"📊 Total IoT records stored: {total_records}")

if total_records > 0:
    try:
        # Retrieve the first stored record from the smart contract
        record = contract.functions.getData(0).call()
        print(
            f"📄 First Record: "
            f"Timestamp={record[0]}, "
            f"PackageId={record[1]}, "
            f"Temperature={record[2]}, "
            f"Latitude={record[3]}, "
            f"Longitude={record[4]}, "
            f"Status={record[5]}, "
            f"RFID Tag={record[6]}, "
            f"Humidity={record[7]}"
        )
    except Exception as e:
        print(f"❌ Failed to retrieve the first record: {e}")
else:
    print("⚠️ No records found.")
# Out:
# 📦 Row Data | PackageId: SHP980988 | ✅ Txn Hash: 3b95cae437f7e92bcea3d643176788647236056c4f1a345d197c13904c2de645
# 📦 Row Data | PackageId: SHP650973 | ✅ Txn Hash: 1dca0aec6f13185b80ccd2ec9e2a1c9db3e260b74ccbf6b34ea1ad9427c8e40e
# 📦 Row Data | PackageId: SHP339067 | ✅ Txn Hash: 8905820e06fc8a7a8e66a19851f84fc21a124dfb29ba248c2bfae4959cee8245
# 📦 Row Data | PackageId: SHP328994 | ✅ Txn Hash: 7462a81889ac97914e374a7f62fd6b2ae41e7f7fb75f5558a3e88ef90a4b64d8
# 📦 Row Data | PackageId: SHP634775 | ✅ Txn Hash: 03c2f5699bfd25e29d8e94ad2962eaba1b6b4da8b96e269ebba6b8cc02716968
# 📦 Row Data | PackageId: SHP740472 | ✅ Txn Hash: 8505b900c43388398db8424eaed7603d53bb8fa11245637673e27658265b8171
# 📦 Row Data | PackageId: SHP600852 | ✅ Txn Hash: ff1e4ea8c38451b50c3bf1f37ef796f2c4d6dd00df46bc766fe19dee8e8e0293
# 📦 Row Data | PackageId: SHP826649 | ✅ Txn Hash: b1f4ff61d87b0365be80cca024392a9f0b436dacf8789c54e32b6bdee4367da3
# 📦 Row Data | PackageId: SHP658564 | ✅ Txn Hash: 60bf60d85ad2a48f9e158540e96295c274969b5f49f53bb035b37d2cc36ed86d
# 📦 Row Data | PackageId: SHP691368 | ✅ Txn Hash: 9d9e4a3175b90379f232e46b41f5d30cfa6b989968b69c35872101ef99202b9d
# 📦 Row Data | PackageId: SHP215221 | ✅ Txn Hash: bebfb5d069e42b5a3ab449caf3b0fd4a6575eb7f4088a5a6bdaaf68119b32d35
# 📦 Row Data | PackageId: SHP953174 | ✅ Txn Hash: dcc6fac9994d335e29770199454dbf4f73694f681d4da82d7b572f19270a8695
# 📦 Row Data | PackageId: SHP568912 | ✅ Txn Hash: 21d93ce6df547fb0b26cbafaa9a33270de51e1e21752b35e1692cb6fb6263b37
# 📦 Row Data | PackageId: SHP426348 | ✅ Txn Hash: 8422878a7aabaf84309180c0f38cdc86f433f1a99d83170966fc6eb49b303c1c
# 📦 Row Data | PackageId: SHP580830 | ✅ Txn Hash: c26d7cac9344010993db7ada94b7c21b7158c846c413a7a68db745cdfbf31c69
# 📦 Row Data | PackageId: SHP556625 | ✅ Txn Hash: 60da8ae5b4e30a9eeefbee04beb948b9480a3273065a2875b649b435a7342704
# 📦 Row Data | PackageId: SHP318088 | ✅ Txn Hash: b47b67b2849a0f661e0595a86b5b3955eab3c2d66144c9069af982b05b255cd0
# 📦 Row Data | PackageId: SHP634605 | ✅ Txn Hash: 2d03fcfb7464398628749f04143cafe96f5e554f132d647400d182dd7b21e8a9
# 📦 Row Data | PackageId: SHP998778 | ✅ Txn Hash: f75f69afd10a89d6a520eb0f916d21534ea635e0c2145694701166efb71dc556
# 📦 Row Data | PackageId: SHP177707 | ✅ Txn Hash: bad8a2c28ea634d25cbef6e0dccf74bf39543e027780780ff2032e35d32daa9d
# 📦 Row Data | PackageId: SHP709628 | ✅ Txn Hash: 6cb5cf30c02c5fee09d46df31694975571f7f9e2a01131bcb00129cec4294e72
# 📦 Row Data | PackageId: SHP241936 | ✅ Txn Hash: cea601a1bce3509180e1c435b17c33d7546e427c31fb6256e9fe597020500f72
# 📦 Row Data | PackageId: SHP330380 | ✅ Txn Hash: 4a696142e29a311c7f349fccf6c4f39e28ca892c001c4b9ac7eb8a5017c3b246
# 📦 Row Data | PackageId: SHP796588 | ✅ Txn Hash: 74872090c9c99ce563e56ae7fade3f710e3c0854d4d5a4db95cc51385b9b8122
# 📦 Row Data | PackageId: SHP990568 | ✅ Txn Hash: d682d434a0e56467de814d7b3f9645262bb4dd1fb4fb0b5a1da4ffc19b3fe4be
# 📦 Row Data | PackageId: SHP264350 | ✅ Txn Hash: 220e5007b114d3b009124c54b75fbfc28e22b6638595fccf78a2c03177105b9e
# 📦 Row Data | PackageId: SHP773798 | ✅ Txn Hash: e11b3230aeab0489bdbe1797df60cdf786f13777bb0a3dcaa317bacaf6114b70
# 📦 Row Data | PackageId: SHP608728 | ✅ Txn Hash: 6b12fdeecab4c1b2291abe7216cd95d5e8e2d979cbf2dd451947e29b48c67068
# 📦 Row Data | PackageId: SHP141010 | ✅ Txn Hash: 3cf15cbff888695b53e368c71ca848be1f16e0e3367fd52ef6df608963975c3c
# 📦 Row Data | PackageId: SHP774464 | ✅ Txn Hash: 17847ef0b68f24ceaa612180275c65c2effcbba629ed2d800a987f36384ccc3a
# 📦 Row Data | PackageId: SHP611919 | ✅ Txn Hash: 570cdbc0e37ef4067d3c04aadc205c165455cd3723d973522bdfa7e1f8d823b3
# 📦 Row Data | PackageId: SHP109816 | ✅ Txn Hash: 1c6829d2dcb7b8ef1771dcf36c9f1456e6936473d11ed9b72464e227e693ee3f
# 📦 Row Data | PackageId: SHP229998 | ✅ Txn Hash: 9b6d3bb81b6a7d6c4b1002b3b1573ffcda64443d27e711d8146b3b983f3f74ac
# 📦 Row Data | PackageId: SHP366512 | ✅ Txn Hash: 2811b9ebf201a1d5eb2b2c5d37f3a3ac6874f9f0bbd4cd9a1ea4c0490742d2f6
# 📦 Row Data | PackageId: SHP607606 | ✅ Txn Hash: bbab7ac7b2a114425a8e6a2ed5f078c5bee1b0fda964c3ef4e7e1a77058c0782
# 📦 Row Data | PackageId: SHP554983 | ✅ Txn Hash: 25b32469e1eb3c61821461d12d650ebd8100986faf69d8389ffacc0ac417b098
# 📦 Row Data | PackageId: SHP528048 | ✅ Txn Hash: 89227aa80d4e58305d06d33058a7f7aefe1e1c343dde632c496eb08fc3a7e115
# 📦 Row Data | PackageId: SHP269829 | ✅ Txn Hash: 9443ae64c0a03665cd6b04a56c035adc7d2c97967c9b18cd0a3b09f552366d0c
# 📦 Row Data | PackageId: SHP329804 | ✅ Txn Hash: 0f68a610903f70bbffa577b7e1f64bef90895f3236fd2cbaf78b41f56cb9fdfa
# 📦 Row Data | PackageId: SHP534914 | ✅ Txn Hash: 808032aa143e2b2641ef5c0d1d4d49618755eccb30c6043e0801e48b8fbbf314
# 📦 Row Data | PackageId: SHP490031 | ✅ Txn Hash: da01ee7ee85d9b63c9adee631567a23473854d00eb24721d09519cc43b1d106a
# 📦 Row Data | PackageId: SHP186780 | ✅ Txn Hash: bc4be7c59325343c5dc30bef476648c2ccf00b7aa365c80727c4b5388b7ee8ab
# 📦 Row Data | PackageId: SHP863344 | ✅ Txn Hash: b00476a20400b16ba17ce9f507e9bd711f3fa5dce4e9dd9a0983d2721f1d22d1
# 📦 Row Data | PackageId: SHP705107 | ✅ Txn Hash: 1575b00de7287c76f7eb1c4e8b30dd9655af92a87b29da74cb65e4a622da9745
# 📦 Row Data | PackageId: SHP872145 | ✅ Txn Hash: 23370d1e75bb0ecbe1f51ad7fa40718eb75b6e58b7d46bc440103d286fb7c623
# 📦 Row Data | PackageId: SHP952511 | ✅ Txn Hash: 6a15b1ae0729dcd75f1534f200c370ecb341b67863d9ae12a046e223d5513ae7
# 📦 Row Data | PackageId: SHP557978 | ✅ Txn Hash: cd134805f56ca4843508d59636e354f519eb68b374001f8ea5aa12e71314ec7e
# 📦 Row Data | PackageId: SHP565542 | ✅ Txn Hash: b24cf48226e777a869bddbce26e0fbdb6cd491c2af2118fc3cd23f88150cc390
# 📦 Row Data | PackageId: SHP749526 | ✅ Txn Hash: c325fca741f9635c204e9de8dcbfce710a8913e66d69b291a2235a8e3929b964
# 📦 Row Data | PackageId: SHP236398 | ✅ Txn Hash: 366c456a59eb8a3dfcc7be00e05530cca2d336f3aaf17ae4dab4fbbbf5186a4e
# 📦 Row Data | PackageId: SHP843084 | ✅ Txn Hash: 8376b2ba678294952fdc02bc2cb330d94ae471692984a39f50d949ba138efc61
# 📦 Row Data | PackageId: SHP113417 | ✅ Txn Hash: f723d64d90d1e42de6bf4766507cce5e42c142b41c7543c57d9361f782c6ce02
# 📦 Row Data | PackageId: SHP968458 | ✅ Txn Hash: a61bb05a1e195b9af63c5477687047bec8cbde7c63c3fc9e797aed290a764270
# 📦 Row Data | PackageId: SHP336999 | ✅ Txn Hash: c1500aa04442581dad039c20a074e1e413b8cb017bdd8156c751d6bf932b3f55
# 📦 Row Data | PackageId: SHP632885 | ✅ Txn Hash: 55d1c919f88407cc53c824ea16b9aa4047002721db5cb007cdc606c7d1500b75
# 📦 Row Data | PackageId: SHP541955 | ✅ Txn Hash: b04e0a7ce6fb43505747881405848c920bffd18e02f39584f13ed7c3e2aa9cf8
# 📦 Row Data | PackageId: SHP622898 | ✅ Txn Hash: 1030e2619f67ccbeb502ea68c24f5360d5df04114095118ce29522012eaae2ce
# 📦 Row Data | PackageId: SHP256651 | ✅ Txn Hash: 544a9e5ea6a9f16eff64df633d245a637e27e27f7d8741842037df5971aa68d6
# 📦 Row Data | PackageId: SHP793998 | ✅ Txn Hash: 00512a9a12ea2ffdc98e5f90943978b8821d2a36383a4ee169693ddbe44463d3
# 📦 Row Data | PackageId: SHP739852 | ✅ Txn Hash: 2fc7b738aa59022a68bec0930392135747469aeecbd1e2b6a47bb6bc5a1d401a
# 📦 Row Data | PackageId: SHP416497 | ✅ Txn Hash: 31085547ccd68b5494347c20b213c59af58e747a3d5f40a700d917b01b9051e3
# 📦 Row Data | PackageId: SHP330418 | ✅ Txn Hash: 7210c90ffd95bc8e68446907dc008f751236835629d3a6d502d0a139cfb7ff14
# 📦 Row Data | PackageId: SHP556375 | ✅ Txn Hash: cc704c42b7107bae0ead1ea89ad1828a1c38a97e0decb7beb865fc588c0ba4c6
# 📦 Row Data | PackageId: SHP967473 | ✅ Txn Hash: 204ecfce5f14711347ebae58bd8f5c93607a41c9a481c0da8be8ca18602a5c06
# 📦 Row Data | PackageId: SHP412723 | ✅ Txn Hash: ffc5e26df852f50a03c85ce1cb12a0c7af37e919074063e0a8a072dd4dc13e66
# 📦 Row Data | PackageId: SHP934221 | ✅ Txn Hash: e65d39b5b4a92859f6bd7e22d9a9f2edd19bb389e85a886121b867190d383382
# 📦 Row Data | PackageId: SHP409631 | ✅ Txn Hash: cde0ba81982c77c73e09fc3595aeb815ac622e40633b401273642e0497e86017
# 📦 Row Data | PackageId: SHP238777 | ✅ Txn Hash: c5c720e99ca9bd64309df3d1c129270aa8c171109ab17a74214760ac1dcc5129
# 📦 Row Data | PackageId: SHP846046 | ✅ Txn Hash: e8380051312b4140dc75d29b48d2f01099eb0f3bae140705c0017df279811d52
# 📦 Row Data | PackageId: SHP728554 | ✅ Txn Hash: 97e9a1ca512efb8b07ffba2a98b1cbbaf96fd941bac5439147bab5e7b92ea631
# 📦 Row Data | PackageId: SHP644220 | ✅ Txn Hash: 9e1b8094789633c8787d78816158bcf25ff27a0bc67b1875622600aab7d218d0
# 📦 Row Data | PackageId: SHP541286 | ✅ Txn Hash: b3d4e726a30b5baeba5162c08987a7674ac3e0faefbf86dcf9e987ffe14dfb90
# 📦 Row Data | PackageId: SHP521638 | ✅ Txn Hash: 9c1de9ef9bc08ef55487445f393244552c9bf300da5fee20c64c9cc4671b8645
# 📦 Row Data | PackageId: SHP123313 | ✅ Txn Hash: dd975303f336404eee1262d2d24a54deb67f983d6dcba3fb9f4da4434ba31195
# 📦 Row Data | PackageId: SHP883683 | ✅ Txn Hash: b63d6d6763d3a14d9a1e8600e1238114cf072333111ea47b3d9d779dfce9b74f
# 📦 Row Data | PackageId: SHP530950 | ✅ Txn Hash: 73278bc65cceb33e18b649d7d973133f55be2e2847b854148136e50666622915
# 📦 Row Data | PackageId: SHP430871 | ✅ Txn Hash: d897b6c28665998a6d013d13830149ccca62d8edaa2af20caa706da4954a8a02
# 📦 Row Data | PackageId: SHP892109 | ✅ Txn Hash: c13c7f4ee9ef8c5aa32c8101d372978017e9919b56ead96301bbd5eda5b877aa
# 📦 Row Data | PackageId: SHP390435 | ✅ Txn Hash: d8b14530e7363bf3e6b9f2aa210aca5052dbc0d5ad97dcea9a32ecb5cc9339d5
# 📦 Row Data | PackageId: SHP623255 | ✅ Txn Hash: d794ccdf449478816c3d8830de4cabb041abcb186892f98eff29ce3627930981
# 📦 Row Data | PackageId: SHP117659 | ✅ Txn Hash: 99beabbdb91e1abbc4285aa06a5b3c23693b72c0492963f49b8ca7077736dac3
# 📦 Row Data | PackageId: SHP395029 | ✅ Txn Hash: 2840d8825676db517e3d1876c3b380941cf736ce205144318dd8f0c220023ba9
# 📦 Row Data | PackageId: SHP400605 | ✅ Txn Hash: dc350253a925c1c65c943e6534ec0b6e8f018f2ff0de97614c66073c2c00f802
# 📦 Row Data | PackageId: SHP367826 | ✅ Txn Hash: 45ac53f2d2a93b7d73719011719099c9fa218ec9a2b59412d5247b199009a2f0
# 📦 Row Data | PackageId: SHP839101 | ✅ Txn Hash: 7931254935a3bb07847e7aabc18136e528b53d882dda8046af862da88127cadc
# 📦 Row Data | PackageId: SHP185176 | ✅ Txn Hash: da01a173ff97ac460a5bc3825dd7ac725b5699f22bf6ab6cba4d2aa8a40cbe74
# 📦 Row Data | PackageId: SHP545079 | ✅ Txn Hash: 3cd9c17773ecde5e1407c845c198e819de7959b0021294f05427849758d0a7de
# 📦 Row Data | PackageId: SHP905681 | ✅ Txn Hash: e71df5186a7fff37763668445b706cc9ef10ff5ad3f09e3fe4e69bc4d9e8a11e
# 📦 Row Data | PackageId: SHP479380 | ✅ Txn Hash: 4afde28796ca8e63ffd545db9192b79f70ee7de4bb026978a4046a36d6b0123d
# 📦 Row Data | PackageId: SHP368600 | ✅ Txn Hash: 5f51a1ea34c9da165378fa35e1a3f00cc6815b475b18f928d43535e9e6c445e2
# 📦 Row Data | PackageId: SHP511918 | ✅ Txn Hash: 8e1781a598f6508b2413a783ce3afa513dac1eb307fa07a38a25aed547983719
# 📦 Row Data | PackageId: SHP835655 | ✅ Txn Hash: 5ecb4c46136bdcd5aad78ed950c5ae9673ca1d4a46e236801c9aa15af6b91a21
# 📦 Row Data | PackageId: SHP498416 | ✅ Txn Hash: ce4541b4d3ead25036ca4c6e6cbc8a9855802f405abb9ada00791705a02e64f4
# 📦 Row Data | PackageId: SHP332425 | ✅ Txn Hash: 40c9413847202faf17df5800e8635d540eac4585cf0041632fada50f95fc7523
# 📦 Row Data | PackageId: SHP452490 | ✅ Txn Hash: 30d3b7bff9a3b1890c5bec74d55c5683fbde504fa3177131f6c69dd2d1e2d254
# 📦 Row Data | PackageId: SHP977623 | ✅ Txn Hash: 9b9357465a134aafeed85e171c47c06c50441f1e9632402cd814a075092e14e5
# 📦 Row Data | PackageId: SHP395905 | ✅ Txn Hash: 77a320e05de2bc63438a16e8e0397ba19a500139b64ab10a646af64d8b301ca7
# 📦 Row Data | PackageId: SHP578667 | ✅ Txn Hash: 4ef99fa921341cbf5504c8f6cbb6ca2d76cdc4a68934758552c6fefd3d03a55d
# 📦 Row Data | PackageId: SHP249701 | ✅ Txn Hash: 0803913abee7532bc5d21e026ef579aadbc0d8fd30bd82d761925f5c87de9905
# 📦 Row Data | PackageId: SHP560143 | ✅ Txn Hash: bda99424ea89935ddbb81b56b9de4b8fe0f08213e62a5419c04d1fb1f70e3705
# 📊 Total IoT records stored: 100
# 📄 First Record: Timestamp=1749477439, PackageId=SHP980988, Temperature=6.8°C, Latitude=11.721861, Longitude=122.739816, Status=In Transit, RFID Tag=RFID1098, Humidity=43.68%
